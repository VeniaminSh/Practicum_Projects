# %% [markdown]
# # Проектная работа. Анализ бизнес-показателей развлекательного приложения Procrastinate Pro+

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Шаг.-Загрузка-данных-и-подготовка-их-к-анализу" data-toc-modified-id="Шаг.-Загрузка-данных-и-подготовка-их-к-анализу-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Шаг. Загрузка данных и подготовка их к анализу</a></span></li><li><span><a href="#Шаг.-Задать-функции-для-расчёта-и-анализа-LTV,-ROI,-удержания-и-конверсии." data-toc-modified-id="Шаг.-Задать-функции-для-расчёта-и-анализа-LTV,-ROI,-удержания-и-конверсии.-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Шаг. Задать функции для расчёта и анализа LTV, ROI, удержания и конверсии.</a></span><ul class="toc-item"><li><span><a href="#Функции-для-вычисления-значений-метрик:" data-toc-modified-id="Функции-для-вычисления-значений-метрик:-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Функции для вычисления значений метрик:</a></span></li><li><span><a href="#Функции-для-построения-графиков:" data-toc-modified-id="Функции-для-построения-графиков:-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Функции для построения графиков:</a></span></li></ul></li><li><span><a href="#Шаг.-Исследовательский-анализ-данных" data-toc-modified-id="Шаг.-Исследовательский-анализ-данных-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Шаг. Исследовательский анализ данных</a></span><ul class="toc-item"><li><span><a href="#Составим-профили-пользователей-и-определим-минимальную-и-максимальную-даты-привлечения-пользователей." data-toc-modified-id="Составим-профили-пользователей-и-определим-минимальную-и-максимальную-даты-привлечения-пользователей.-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Составим профили пользователей и определим минимальную и максимальную даты привлечения пользователей.</a></span></li><li><span><a href="#Выясним,-из-каких-стран-пользователи-приходят-в-приложение-и-на-какую-страну-приходится-больше-всего-платящих-пользователей.-Построим-таблицу,-отражающую-количество-пользователей-и-долю-платящих-из-каждой-страны." data-toc-modified-id="Выясним,-из-каких-стран-пользователи-приходят-в-приложение-и-на-какую-страну-приходится-больше-всего-платящих-пользователей.-Построим-таблицу,-отражающую-количество-пользователей-и-долю-платящих-из-каждой-страны.-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Выясним, из каких стран пользователи приходят в приложение и на какую страну приходится больше всего платящих пользователей. Построим таблицу, отражающую количество пользователей и долю платящих из каждой страны.</a></span></li><li><span><a href="#Узнаем,-какими-устройствами-пользуются-клиенты-и-какие-устройства-предпочитают-платящие-пользователи.-Построем-таблицу,-отражающую-количество-пользователей-и-долю-платящих-для-каждого-устройства." data-toc-modified-id="Узнаем,-какими-устройствами-пользуются-клиенты-и-какие-устройства-предпочитают-платящие-пользователи.-Построем-таблицу,-отражающую-количество-пользователей-и-долю-платящих-для-каждого-устройства.-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Узнаем, какими устройствами пользуются клиенты и какие устройства предпочитают платящие пользователи. Построем таблицу, отражающую количество пользователей и долю платящих для каждого устройства.</a></span></li><li><span><a href="#Изучим-рекламные-источники-привлечения-и-определите-каналы,-из-которых-пришло-больше-всего-платящих-пользователей.-Построим-таблицу,-отражающую-количество-пользователей-и-долю-платящих-для-каждого-канала-привлечения." data-toc-modified-id="Изучим-рекламные-источники-привлечения-и-определите-каналы,-из-которых-пришло-больше-всего-платящих-пользователей.-Построим-таблицу,-отражающую-количество-пользователей-и-долю-платящих-для-каждого-канала-привлечения.-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Изучим рекламные источники привлечения и определите каналы, из которых пришло больше всего платящих пользователей. Построим таблицу, отражающую количество пользователей и долю платящих для каждого канала привлечения.</a></span></li></ul></li><li><span><a href="#Шаг.-Маркетинг" data-toc-modified-id="Шаг.-Маркетинг-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Шаг. Маркетинг</a></span><ul class="toc-item"><li><span><a href="#Посчитайте-общую-сумму-расходов-на-маркетинг." data-toc-modified-id="Посчитайте-общую-сумму-расходов-на-маркетинг.-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Посчитайте общую сумму расходов на маркетинг.</a></span></li><li><span><a href="#Выясните,-как-траты-распределены-по-рекламным-источникам,-то-есть-сколько-денег-потратили-на-каждый-источник." data-toc-modified-id="Выясните,-как-траты-распределены-по-рекламным-источникам,-то-есть-сколько-денег-потратили-на-каждый-источник.-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Выясните, как траты распределены по рекламным источникам, то есть сколько денег потратили на каждый источник.</a></span></li><li><span><a href="#Постройте-визуализацию-динамики-изменения-расходов-во-времени-(по-неделям-и-месяцам)-по-каждому-источнику.-Постарайтесь-отразить-это-на-одном-графике." data-toc-modified-id="Постройте-визуализацию-динамики-изменения-расходов-во-времени-(по-неделям-и-месяцам)-по-каждому-источнику.-Постарайтесь-отразить-это-на-одном-графике.-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Постройте визуализацию динамики изменения расходов во времени (по неделям и месяцам) по каждому источнику. Постарайтесь отразить это на одном графике.</a></span></li><li><span><a href="#Узнаем,-сколько-в-среднем-стоит-привлечение-одного-пользователя-(CAC)-из-каждого-источника.-Используйте-профили-пользователей." data-toc-modified-id="Узнаем,-сколько-в-среднем-стоит-привлечение-одного-пользователя-(CAC)-из-каждого-источника.-Используйте-профили-пользователей.-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Узнаем, сколько в среднем стоит привлечение одного пользователя (CAC) из каждого источника. Используйте профили пользователей.</a></span></li></ul></li><li><span><a href="#Шаг-.-Оценим-окупаемость-рекламы" data-toc-modified-id="Шаг-.-Оценим-окупаемость-рекламы-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Шаг . Оценим окупаемость рекламы</a></span><ul class="toc-item"><li><span><a href="#Проанализируем-окупаемость-рекламы-c-помощью-графиков-LTV-и-ROI,-а-также-графики-динамики-LTV,-CAC-и-ROI." data-toc-modified-id="Проанализируем-окупаемость-рекламы-c-помощью-графиков-LTV-и-ROI,-а-также-графики-динамики-LTV,-CAC-и-ROI.-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Проанализируем окупаемость рекламы c помощью графиков LTV и ROI, а также графики динамики LTV, CAC и ROI.</a></span></li><li><span><a href="#Проверим-конверсию-пользователей-и-динамику-её-изменения.-То-же-самое-сделайте-с-удержанием-пользователей.-Постройте-и-изучите-графики-конверсии-и-удержания." data-toc-modified-id="Проверим-конверсию-пользователей-и-динамику-её-изменения.-То-же-самое-сделайте-с-удержанием-пользователей.-Постройте-и-изучите-графики-конверсии-и-удержания.-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Проверим конверсию пользователей и динамику её изменения. То же самое сделайте с удержанием пользователей. Постройте и изучите графики конверсии и удержания.</a></span><ul class="toc-item"><li><span><a href="#Страны" data-toc-modified-id="Страны-5.2.1"><span class="toc-item-num">5.2.1&nbsp;&nbsp;</span>Страны</a></span></li><li><span><a href="#Устройства" data-toc-modified-id="Устройства-5.2.2"><span class="toc-item-num">5.2.2&nbsp;&nbsp;</span>Устройства</a></span></li><li><span><a href="#Рекламные-каналы" data-toc-modified-id="Рекламные-каналы-5.2.3"><span class="toc-item-num">5.2.3&nbsp;&nbsp;</span>Рекламные каналы</a></span></li></ul></li><li><span><a href="#Проанализируем-окупаемость-рекламы-с-разбивкой-по-устройствам.-Построем-графики-LTV-и-ROI,-а-также-графики-динамики-LTV,-CAC-и-ROI." data-toc-modified-id="Проанализируем-окупаемость-рекламы-с-разбивкой-по-устройствам.-Построем-графики-LTV-и-ROI,-а-также-графики-динамики-LTV,-CAC-и-ROI.-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>Проанализируем окупаемость рекламы с разбивкой по устройствам. Построем графики LTV и ROI, а также графики динамики LTV, CAC и ROI.</a></span></li><li><span><a href="#Проанализируем-окупаемость-рекламы-с-разбивкой-по-странам.-Построем-графики-LTV-и-ROI,-а-также-графики-динамики-LTV,-CAC-и-ROI." data-toc-modified-id="Проанализируем-окупаемость-рекламы-с-разбивкой-по-странам.-Построем-графики-LTV-и-ROI,-а-также-графики-динамики-LTV,-CAC-и-ROI.-5.4"><span class="toc-item-num">5.4&nbsp;&nbsp;</span>Проанализируем окупаемость рекламы с разбивкой по странам. Построем графики LTV и ROI, а также графики динамики LTV, CAC и ROI.</a></span></li><li><span><a href="#Проанализируем-окупаемость-рекламы-с-разбивкой-по-рекламным-каналам.-Построем-графики-LTV-и-ROI,-а-также-графики-динамики-LTV,-CAC-и-ROI." data-toc-modified-id="Проанализируем-окупаемость-рекламы-с-разбивкой-по-рекламным-каналам.-Построем-графики-LTV-и-ROI,-а-также-графики-динамики-LTV,-CAC-и-ROI.-5.5"><span class="toc-item-num">5.5&nbsp;&nbsp;</span>Проанализируем окупаемость рекламы с разбивкой по рекламным каналам. Построем графики LTV и ROI, а также графики динамики LTV, CAC и ROI.</a></span></li><li><span><a href="#Окупается-ли-реклама,-направленная-на-привлечение-пользователей-в-целом?" data-toc-modified-id="Окупается-ли-реклама,-направленная-на-привлечение-пользователей-в-целом?-5.6"><span class="toc-item-num">5.6&nbsp;&nbsp;</span>Окупается ли реклама, направленная на привлечение пользователей в целом?</a></span></li><li><span><a href="#Какие-устройства,-страны-и-рекламные-каналы-могут-оказывать-негативное-влияние-на-окупаемость-рекламы?" data-toc-modified-id="Какие-устройства,-страны-и-рекламные-каналы-могут-оказывать-негативное-влияние-на-окупаемость-рекламы?-5.7"><span class="toc-item-num">5.7&nbsp;&nbsp;</span>Какие устройства, страны и рекламные каналы могут оказывать негативное влияние на окупаемость рекламы?</a></span></li><li><span><a href="#Чем-могут-быть-вызваны-проблемы-окупаемости?" data-toc-modified-id="Чем-могут-быть-вызваны-проблемы-окупаемости?-5.8"><span class="toc-item-num">5.8&nbsp;&nbsp;</span>Чем могут быть вызваны проблемы окупаемости?</a></span></li></ul></li><li><span><a href="#Шаг-.-Напишите-выводы" data-toc-modified-id="Шаг-.-Напишите-выводы-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Шаг . Напишите выводы</a></span><ul class="toc-item"><li><span><a href="#Выделим-причины-неэффективности-привлечения-пользователей." data-toc-modified-id="Выделим-причины-неэффективности-привлечения-пользователей.-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Выделим причины неэффективности привлечения пользователей.</a></span></li><li><span><a href="#Сформулируйте-рекомендации-для-отдела-маркетинга." data-toc-modified-id="Сформулируйте-рекомендации-для-отдела-маркетинга.-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>Сформулируйте рекомендации для отдела маркетинга.</a></span></li></ul></li></ul></div>

# %% [markdown]
# ---

# %% [markdown]
# В данном проекте из открытых источников представлены исторические данные о пользователях, привлечённых с 1 мая по 27 октября 2019 года:
#
# - лог сервера с данными об их посещениях,
# - выгрузка их покупок за этот период,
# - рекламные расходы.
#
# Ниже представлен список вопросов, которые будут рассмотрены в данном проекте
#
# - откуда приходят пользователи и какими устройствами они пользуются,
# - сколько стоит привлечение пользователей из различных рекламных каналов;
# - сколько денег приносит каждый клиент,
# - когда расходы на привлечение клиента окупаются,
# - какие факторы мешают привлечению клиентов.

# %% [markdown]
# **Основная цель проекта**: Несмотря на огромные вложения в рекламу, последние несколько месяцев компания терпит убытки нам необходимо разобраться в причинах и помочь компании выйти в плюс.

# %% [markdown]
# <blockquote>Проект разбит на 6 шагов::<ol>
#
# <li>Шаг. Загрузка данных и подготовка их к анализу</li>
# <li>Шаг. Задать функции для расчёта и анализа LTV, ROI, удержания и конверсии.</li>
# <li>Шаг. Исследовательский анализ данных</li>
# <li>Шаг. Маркетинг</li>
# <li>Шаг. Оцените окупаемость рекламы</li>
# <li>Шаг. Написать выводы</li>
# </ol>
# </blockquote>

# %% [markdown]
# ### Шаг. Загрузка данных и подготовка их к анализу

# %%
#подключаем библиотеки
import pandas as pd
import numpy as np
import datetime
from datetime import date, datetime, timedelta
from matplotlib import pyplot as plt
import seaborn as sns
import math
import requests 
from urllib.parse import urlencode

# %%
#прочитаем файлы
try:
    visit = pd.read_csv('C:\\Users\\Вениамин\\Desktop\\Аналитик Данных\\проекты\\Проект 4 (СБОРНЫЙ)\\visits_info_short.csv')
    order = pd.read_csv('C:\\Users\\Вениамин\\Desktop\\Аналитик Данных\\проекты\\Проект 4 (СБОРНЫЙ)\\orders_info_short.csv')
    costs = pd.read_csv('C:\\Users\\Вениамин\\Desktop\\Аналитик Данных\\проекты\\Проект 4 (СБОРНЫЙ)\\costs_info_short.csv')
except:
    visit = pd.read_csv('https://code.s3.yandex.net/datasets/visits_info_short.csv')
    order = pd.read_csv('https://code.s3.yandex.net/datasets/orders_info_short.csv')
    costs = pd.read_csv('https://code.s3.yandex.net/datasets/costs_info_short.csv')

# %%
#Посмотрим на данные
display(visit.head())
display(order.head())
costs.head()
# Out:
#         User Id         Region   Device  Channel        Session Start  \
# 0  981449118918  United States   iPhone  organic  2019-05-01 02:36:01
# 1  278965908054  United States   iPhone  organic  2019-05-01 04:46:31
# 2  590706206550  United States      Mac  organic  2019-05-01 14:09:25
# 3  326433527971  United States  Android   TipTop  2019-05-01 00:29:59
# 4  349773784594  United States      Mac  organic  2019-05-01 03:33:35
#
#            Session End
# 0  2019-05-01 02:45:01
# 1  2019-05-01 04:47:35
# 2  2019-05-01 15:32:08
# 3  2019-05-01 00:54:25
# 4  2019-05-01 03:57:40
#         User Id             Event Dt  Revenue
# 0  188246423999  2019-05-01 23:09:52     4.99
# 1  174361394180  2019-05-01 12:24:04     4.99
# 2  529610067795  2019-05-01 11:34:04     4.99
# 3  319939546352  2019-05-01 15:34:40     4.99
# 4  366000285810  2019-05-01 13:59:51     4.99
#            dt   Channel  costs
# 0  2019-05-01  FaceBoom  113.3
# 1  2019-05-02  FaceBoom   78.1
# ...

# %%
#переименуем столбцы
visit.columns = [x.lower().replace(' ', '_') for x in visit.columns.values]
order.columns = [x.lower().replace(' ', '_') for x in order.columns.values]
costs.columns = [x.lower().replace(' ', '_') for x in costs.columns.values]

# %%
#проверим
display(visit.head())
display(order.head())
costs.head()
# Out:
#         user_id         region   device  channel        session_start  \
# 0  981449118918  United States   iPhone  organic  2019-05-01 02:36:01
# 1  278965908054  United States   iPhone  organic  2019-05-01 04:46:31
# 2  590706206550  United States      Mac  organic  2019-05-01 14:09:25
# 3  326433527971  United States  Android   TipTop  2019-05-01 00:29:59
# 4  349773784594  United States      Mac  organic  2019-05-01 03:33:35
#
#            session_end
# 0  2019-05-01 02:45:01
# 1  2019-05-01 04:47:35
# 2  2019-05-01 15:32:08
# 3  2019-05-01 00:54:25
# 4  2019-05-01 03:57:40
#         user_id             event_dt  revenue
# 0  188246423999  2019-05-01 23:09:52     4.99
# 1  174361394180  2019-05-01 12:24:04     4.99
# 2  529610067795  2019-05-01 11:34:04     4.99
# 3  319939546352  2019-05-01 15:34:40     4.99
# 4  366000285810  2019-05-01 13:59:51     4.99
#            dt   channel  costs
# 0  2019-05-01  FaceBoom  113.3
# 1  2019-05-02  FaceBoom   78.1
# ...

# %%
#посмотрим информацию о типе данных
display(visit.info())
display(order.info())
display(costs.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309901 entries, 0 to 309900
# Data columns (total 6 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   user_id        309901 non-null  int64
#  1   region         309901 non-null  object
#  2   device         309901 non-null  object
#  3   channel        309901 non-null  object
#  4   session_start  309901 non-null  object
#  5   session_end    309901 non-null  object
# dtypes: int64(1), object(5)
# memory usage: 14.2+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40212 entries, 0 to 40211
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   user_id   40212 non-null  int64
#  1   event_dt  40212 non-null  object
#  2   revenue   40212 non-null  float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 942.6+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# ...

# %% [markdown]
# **Вывод:**
#
# Мы имеем 3 датафрейма с данными. Поменяем название столбцов - приведем к нижнему регистру и заменим пропуски между словами на символ. С разными типами столбцов. В каждом из датафреймов помеяем тип данных столбцов.

# %%
#поменяем тип столбцов с датой на datetime
visit['session_start'] = pd.to_datetime(visit['session_start'])
visit['session_end'] = pd.to_datetime(visit['session_end'])
#следом order
order['event_dt'] = pd.to_datetime(order['event_dt'])
#следом costs 
costs['dt'] = pd.to_datetime(costs['dt']).dt.date

# %%
#проверим
display(visit.info())
display(order.info())
display(costs.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309901 entries, 0 to 309900
# Data columns (total 6 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   user_id        309901 non-null  int64
#  1   region         309901 non-null  object
#  2   device         309901 non-null  object
#  3   channel        309901 non-null  object
#  4   session_start  309901 non-null  datetime64[ns]
#  5   session_end    309901 non-null  datetime64[ns]
# dtypes: datetime64[ns](2), int64(1), object(3)
# memory usage: 14.2+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40212 entries, 0 to 40211
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   user_id   40212 non-null  int64
#  1   event_dt  40212 non-null  datetime64[ns]
#  2   revenue   40212 non-null  float64
# dtypes: datetime64[ns](1), float64(1), int64(1)
# memory usage: 942.6 KB
# None
# ...

# %% [markdown]
# ---

# %% [markdown]
# Уникальные характеристики датафрейма `visit`

# %%
#проверим дубликаты
display(visit.duplicated().sum())

#посмотрим на уникальные показатели
display(visit['user_id'].value_counts())
display(visit['region'].value_counts())
display(visit['device'].value_counts())
display(visit['channel'].value_counts())
# Out:
# 0
# 33606575057     46
# 943775408561    36
# 901180916748    35
# 870784569391    34
# 764086596354    33
#                 ..
# 350468480225     1
# 748123264144     1
# 909267360937     1
# 816252757222     1
# 425788122907     1
# Name: user_id, Length: 150008, dtype: int64
# United States    207327
# UK                36419
# France            35396
# Germany           30759
# Name: region, dtype: int64
# iPhone     112603
# Android     72590
# PC          62686
# Mac         62022
# Name: device, dtype: int64
# organic               107760
# TipTop                 54794
# FaceBoom               49022
# WahooNetBanner         20465
# LeapBob                17013
# OppleCreativeMedia     16794
# RocketSuperAds         12724
# YRabbit                 9053
# MediaTornado            8878
# AdNonSense              6891
# lambdaMediaAds          6507
# Name: channel, dtype: int64

# %% [markdown]
# **Вывод:**
# * В датафрейме `visit` 150008 уникальных пользователей. Чаще всего повторяется пользователь с id 33606575057.
# * Уникальных значений в столбце `region` 4, а именно **'United States'** (207327 строк), 'UK', 'France', 'Germany'.
# * Уникальных значиней в столбце `device` 4, а именно **'iPhone'** (112603 строк), 'Mac', 'Android', 'PC'.
# * Уникальных значиней в столбце `channel` 11, а именно **'organic'** (112603 строк), 'TipTop', 'RocketSuperAds', 'YRabbit', 'FaceBoom','MediaTornado', 'AdNonSense', 'LeapBob', 'WahooNetBanner', 'OppleCreativeMedia', 'lambdaMediaAds'.

# %% [markdown]
# ---

# %% [markdown]
# Уникальные характеристики датафрейма `order`

# %%
#проверим дубликаты
display(order.duplicated().sum())
#посмотрим на уникальные показатели order
display(order['user_id'].value_counts())
display(order['revenue'].value_counts())
# Out:
# 0
# 901180916748    22
# 883098437811    20
# 75337957494     19
# 512471511263    19
# 295795879965    19
#                 ..
# 237296010927     1
# 319939546352     1
# 742075710598     1
# 202972423389     1
# 775233404832     1
# Name: user_id, Length: 8881, dtype: int64
# 4.99     38631
# 5.99       780
# 9.99       385
# 49.99      212
# 19.99      204
# Name: revenue, dtype: int64

# %% [markdown]
# **Вывод:**
# * У нас иммется пользователь с id `901180916748`, который сделал 22 заказа.
# * Так же вывели уникальные значения в столбце `revenue` и узнали интересную особенность - скорее всего продажи в приложении осуществляются путем подписок т.к. у нас есть всего 5 вариантов оплаты:
#     * 4.99
#     * 5.99
#     * 9.99
#     * 49.99
#     * 19.99

# %% [markdown]
# ---

# %% [markdown]
# Уникальные характеристики датафрейма `costs`

# %%
#проверим дубликаты
display(order.duplicated().sum())
#посмотрим на уникальные показатели order
display(costs['channel'].value_counts())
display(costs['costs'].describe())
# Out:
# 0
# OppleCreativeMedia    180
# AdNonSense            180
# RocketSuperAds        180
# lambdaMediaAds        180
# YRabbit               180
# MediaTornado          180
# FaceBoom              180
# LeapBob               180
# TipTop                180
# WahooNetBanner        180
# Name: channel, dtype: int64
# count    1800.000000
# mean       58.609611
# std       107.740223
# min         0.800000
# 25%         6.495000
# 50%        12.285000
# 75%        33.600000
# max       630.000000
# Name: costs, dtype: float64

# %% [markdown]
# **Вывод:**
# * Общее количество строк 1800
# * Количество каналов, на которых запускалась реклама - 10, интресная особенность, в каждая из компаний имеет одинаковое количесвто строк.
# * Медиана по затратам на рекламу 12.2, а средняя 58.6 , что говорит нам о наличии выбросов.

# %% [markdown]
# ### Шаг. Задать функции для расчёта и анализа LTV, ROI, удержания и конверсии.

# %% [markdown]
# #### Функции для вычисления значений метрик:

# %% [markdown]
# Создадим функцию для создания пользовательских профилей `get_profiles`

# %%
def get_profiles(sessions, orders, costs):
    # находим параметры первых посещений
    profiles = (
        visit.sort_values(by=['user_id', 'session_start'])
        .groupby('user_id')
        .agg(
            {
                'session_start': 'first',
                'channel': 'first',
                'device': 'first',
                'region': 'first',
            }
        )
        .rename(columns={'session_start': 'first_ts'})
        .reset_index()
    )

    # для когортного анализа определяем дату первого посещения
    # и первый день месяца, в который это посещение произошло
    profiles['dt'] = profiles['first_ts'].dt.date
    profiles['month'] = profiles['first_ts'].astype('datetime64[M]')

    # добавляем признак платящих пользователей
    profiles['payer'] = profiles['user_id'].isin(order['user_id'].unique())

    # считаем количество уникальных пользователей
    # с одинаковыми источником и датой привлечения
    new_users = (
        profiles.groupby(['dt', 'channel'])
        .agg({'user_id': 'nunique'})
        .rename(columns={'user_id': 'unique_users'})
        .reset_index()
    )

    # объединяем траты на рекламу и число привлечённых пользователей
    costs = costs.merge(new_users, on=['dt', 'channel'], how='left')

    # делим рекламные расходы на число привлечённых пользователей
    costs['acquisition_cost'] = costs['costs'] / costs['unique_users']

    # добавляем стоимость привлечения в профили
    profiles = profiles.merge(
        costs[['dt', 'channel', 'acquisition_cost']],
        on=['dt', 'channel'],
        how='left',
    )

    # стоимость привлечения органических пользователей равна нулю
    profiles['acquisition_cost'] = profiles['acquisition_cost'].fillna(0)

    return profiles

# %% [markdown]
# ---

# %% [markdown]
# Создадим функцию для создания пользовательских профилей `get_retention` — для подсчёта Retention Rate

# %%
#для начала нам необходимо установить момент и горизонт анализа данных
observation_date = datetime(2020, 11, 1).date()  # момент анализа
horizon_days = 14  # горизонт анализа
ignore_horizon = False # создаём опцию «игнорировать горизонт»

# %%
# функция для расчёта удержания

def get_retention(
    profiles,
    sessions,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # добавляем столбец payer в передаваемый dimensions список
    dimensions = ['payer'] + dimensions

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')

    # собираем «сырые» данные для расчёта удержания
    result_raw = result_raw.merge(
        visit[['user_id', 'session_start']], on='user_id', how='left'
    )
    result_raw['lifetime'] = (
        result_raw['session_start'] - result_raw['first_ts']
    ).dt.days

    # функция для группировки таблицы по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        result = df.pivot_table(
            index=dims, columns='lifetime', values='user_id', aggfunc='nunique'
        )
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        result = result.div(result['cohort_size'], axis=0)
        result = result[['cohort_size'] + list(range(horizon_days))]
        result['cohort_size'] = cohort_sizes
        return result

    # получаем таблицу удержания
    result_grouped = group_by_dimensions(result_raw, dimensions, horizon_days)

    # получаем таблицу динамики удержания
    result_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    # возвращаем обе таблицы и сырые данные
    return result_raw, result_grouped, result_in_time

# %%
#проверим
result_raw, result_grouped, result_in_time = get_retention(profiles, 
                                                           visit, 
                                                           observation_date, 
                                                           horizon_days, 
                                                           dimensions=['device']
)
display(result_raw)
display(result_grouped)
display(result_in_time)
# Out:
#              user_id            first_ts       channel  device         region  \
# 0             599326 2019-05-07 20:58:57      FaceBoom     Mac  United States
# 1             599326 2019-05-07 20:58:57      FaceBoom     Mac  United States
# 2             599326 2019-05-07 20:58:57      FaceBoom     Mac  United States
# 3            4919697 2019-07-09 12:46:07      FaceBoom  iPhone  United States
# 4            4919697 2019-07-09 12:46:07      FaceBoom  iPhone  United States
# ...              ...                 ...           ...     ...            ...
# 309896  999976332130 2019-07-23 02:57:06        TipTop  iPhone  United States
# 309897  999979924135 2019-09-28 21:28:09  MediaTornado      PC  United States
# 309898  999979924135 2019-09-28 21:28:09  MediaTornado      PC  United States
# 309899  999999563947 2019-10-18 19:57:25       organic  iPhone  United States
# 309900  999999563947 2019-10-18 19:57:25       organic  iPhone  United States
#
# ...

# %% [markdown]
# ---

# %% [markdown]
# Создадим функцию для создания пользовательских профилей `get_conversion` — для подсчёта конверсии.

# %%
def get_conversion(
    profiles,
    purchases,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')

    # определяем дату и время первой покупки для каждого пользователя
    first_purchases = (
        purchases.sort_values(by=['user_id', 'event_dt'])
        .groupby('user_id')
        .agg({'event_dt': 'first'})
        .reset_index()
    )

    # добавляем данные о покупках в профили
    result_raw = result_raw.merge(
        first_purchases[['user_id', 'event_dt']], on='user_id', how='left'
    )

    # рассчитываем лайфтайм для каждой покупки
    result_raw['lifetime'] = (
        result_raw['event_dt'] - result_raw['first_ts']
    ).dt.days

    # группируем по cohort, если в dimensions ничего нет
    if len(dimensions) == 0:
        result_raw['cohort'] = 'All users' 
        dimensions = dimensions + ['cohort']

    # функция для группировки таблицы по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        result = df.pivot_table(
            index=dims, columns='lifetime', values='user_id', aggfunc='nunique'
        )
        result = result.fillna(0).cumsum(axis = 1)
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        # делим каждую «ячейку» в строке на размер когорты
        # и получаем conversion rate
        result = result.div(result['cohort_size'], axis=0)
        result = result[['cohort_size'] + list(range(horizon_days))]
        result['cohort_size'] = cohort_sizes
        return result

    # получаем таблицу конверсии
    result_grouped = group_by_dimensions(result_raw, dimensions, horizon_days)

    # для таблицы динамики конверсии убираем 'cohort' из dimensions
    if 'cohort' in dimensions: 
        dimensions = []

    # получаем таблицу динамики конверсии
    result_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    # возвращаем обе таблицы и сырые данные
    return result_raw, result_grouped, result_in_time

# %%
#проверим
result_raw, result_grouped, result_in_time = get_conversion(
    profiles,
    order,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
)
display(result_raw)
display(result_grouped)
display(result_in_time)
# Out:
#              user_id            first_ts       channel  device         region  \
# 0             599326 2019-05-07 20:58:57      FaceBoom     Mac  United States
# 1            4919697 2019-07-09 12:46:07      FaceBoom  iPhone  United States
# 2            6085896 2019-10-01 09:58:33       organic  iPhone         France
# 3           22593348 2019-08-22 21:35:48    AdNonSense      PC        Germany
# 4           31989216 2019-10-02 00:07:44       YRabbit  iPhone  United States
# ...              ...                 ...           ...     ...            ...
# 150003  999956196527 2019-09-28 08:33:02        TipTop  iPhone  United States
# 150004  999975439887 2019-10-21 00:35:17       organic      PC             UK
# 150005  999976332130 2019-07-23 02:57:06        TipTop  iPhone  United States
# 150006  999979924135 2019-09-28 21:28:09  MediaTornado      PC  United States
# 150007  999999563947 2019-10-18 19:57:25       organic  iPhone  United States
#
# ...

# %% [markdown]
# ---

# %% [markdown]
# Создадим функцию для создания пользовательских профилей `get_ltv` — для подсчёта конверсии.

# %%
def get_ltv(
    profiles,
    order,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')
    # добавляем данные о покупках в профили
    result_raw = result_raw.merge(
        order[['user_id', 'event_dt', 'revenue']], on='user_id', how='left'
    )
    # рассчитываем лайфтайм пользователя для каждой покупки
    result_raw['lifetime'] = (
        result_raw['event_dt'] - result_raw['first_ts']
    ).dt.days
    # группируем по cohort, если в dimensions ничего нет
    if len(dimensions) == 0:
        result_raw['cohort'] = 'All users'
        dimensions = dimensions + ['cohort']

    # функция группировки по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        # строим «треугольную» таблицу выручки
        result = df.pivot_table(
            index=dims, columns='lifetime', values='revenue', aggfunc='sum'
        )
        # находим сумму выручки с накоплением
        result = result.fillna(0).cumsum(axis=1)
        # вычисляем размеры когорт
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        # объединяем размеры когорт и таблицу выручки
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        # считаем LTV: делим каждую «ячейку» в строке на размер когорты
        result = result.div(result['cohort_size'], axis=0)
        # исключаем все лайфтаймы, превышающие горизонт анализа
        result = result[['cohort_size'] + list(range(horizon_days))]
        # восстанавливаем размеры когорт
        result['cohort_size'] = cohort_sizes

        # собираем датафрейм с данными пользователей и значениями CAC, 
        # добавляя параметры из dimensions
        cac = df[['user_id', 'acquisition_cost'] + dims].drop_duplicates()

        # считаем средний CAC по параметрам из dimensions
        cac = (
            cac.groupby(dims)
            .agg({'acquisition_cost': 'mean'})
            .rename(columns={'acquisition_cost': 'cac'})
        )

        # считаем ROI: делим LTV на CAC
        roi = result.div(cac['cac'], axis=0)

        # удаляем строки с бесконечным ROI
        roi = roi[~roi['cohort_size'].isin([np.inf])]

        # восстанавливаем размеры когорт в таблице ROI
        roi['cohort_size'] = cohort_sizes

        # добавляем CAC в таблицу ROI
        roi['cac'] = cac['cac']

        # в финальной таблице оставляем размеры когорт, CAC
        # и ROI в лайфтаймы, не превышающие горизонт анализа
        roi = roi[['cohort_size', 'cac'] + list(range(horizon_days))]

        # возвращаем таблицы LTV и ROI
        return result, roi

    # получаем таблицы LTV и ROI
    result_grouped, roi_grouped = group_by_dimensions(
        result_raw, dimensions, horizon_days
    )

    # для таблиц динамики убираем 'cohort' из dimensions
    if 'cohort' in dimensions:
        dimensions = []

    # получаем таблицы динамики LTV и ROI
    result_in_time, roi_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    return (
        result_raw,  # сырые данные
        result_grouped,  # таблица LTV
        result_in_time,  # таблица динамики LTV
        roi_grouped,  # таблица ROI
        roi_in_time,  # таблица динамики ROI
    )

# %%
#проверим
result_raw, result_grouped, result_in_time, roi_grouped, roi_in_time = get_ltv(
    profiles,
    order,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
)
display(result_raw)
display(result_grouped)
display(result_in_time)
display(roi_grouped)
display(roi_in_time)
# Out:
#              user_id            first_ts       channel  device         region  \
# 0             599326 2019-05-07 20:58:57      FaceBoom     Mac  United States
# 1             599326 2019-05-07 20:58:57      FaceBoom     Mac  United States
# 2             599326 2019-05-07 20:58:57      FaceBoom     Mac  United States
# 3            4919697 2019-07-09 12:46:07      FaceBoom  iPhone  United States
# 4            6085896 2019-10-01 09:58:33       organic  iPhone         France
# ...              ...                 ...           ...     ...            ...
# 181334  999956196527 2019-09-28 08:33:02        TipTop  iPhone  United States
# 181335  999975439887 2019-10-21 00:35:17       organic      PC             UK
# 181336  999976332130 2019-07-23 02:57:06        TipTop  iPhone  United States
# 181337  999979924135 2019-09-28 21:28:09  MediaTornado      PC  United States
# 181338  999999563947 2019-10-18 19:57:25       organic  iPhone  United States
#
# ...

# %% [markdown]
# #### Функции для построения графиков:

# %% [markdown]
# Создадим функцию для сглаживания фрейма `filter_data`.

# %%
# функция для сглаживания фрейма

def filter_data(df, window):
    # для каждого столбца применяем скользящее среднее
    for column in df.columns.values:
        df[column] = df[column].rolling(window).mean() 
    return df

# %% [markdown]
# ---

# %% [markdown]
# Создадим функция для визуализации удержания `plot_retention`.

# %%
def plot_retention(retention, retention_history, horizon, window=7):

    # задаём размер сетки для графиков
    plt.figure(figsize=(15, 10))

    # исключаем размеры когорт и удержание первого дня
    retention = retention.drop(columns=['cohort_size', 0])
    # в таблице динамики оставляем только нужный лайфтайм
    retention_history = retention_history.drop(columns=['cohort_size'])[
        [horizon - 1]
    ]

    # если в индексах таблицы удержания только payer,
    # добавляем второй признак — cohort
    if retention.index.nlevels == 1:
        retention['cohort'] = 'All users'
        retention = retention.reset_index().set_index(['cohort', 'payer'])

    # в таблице графиков — два столбца и две строки, четыре ячейки
    # в первой строим кривые удержания платящих пользователей
    ax1 = plt.subplot(2, 2, 1)
    retention.query('payer == True').droplevel('payer').T.plot(
        grid=True, ax=ax1
    )
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Удержание платящих пользователей')

    # во второй ячейке строим кривые удержания неплатящих
    # вертикальная ось — от графика из первой ячейки
    ax2 = plt.subplot(2, 2, 2, sharey=ax1)
    retention.query('payer == False').droplevel('payer').T.plot(
        grid=True, ax=ax2
    )
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Удержание неплатящих пользователей')

    # в третьей ячейке — динамика удержания платящих
    ax3 = plt.subplot(2, 2, 3)
    # получаем названия столбцов для сводной таблицы
    columns = [
        name
        for name in retention_history.index.names
        if name not in ['dt', 'payer']
    ]
    # фильтруем данные и строим график
    filtered_data = retention_history.query('payer == True').pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax3)
    plt.xlabel('Дата привлечения')
    plt.title(
        'Динамика удержания платящих пользователей на {}-й день'.format(
            horizon
        )
    )

    # в чётвертой ячейке — динамика удержания неплатящих
    ax4 = plt.subplot(2, 2, 4, sharey=ax3)
    # фильтруем данные и строим график
    filtered_data = retention_history.query('payer == False').pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax4)
    plt.xlabel('Дата привлечения')
    plt.title(
        'Динамика удержания неплатящих пользователей на {}-й день'.format(
            horizon
        )
    )
    
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ---

# %% [markdown]
# Создадим функция для построения графика конверсии `plot_conversion`.

# %%
# функция для визуализации конверсии

def plot_conversion(conversion, conversion_history, horizon, window=7):

    # задаём размер сетки для графиков
    plt.figure(figsize=(15, 5))

    # исключаем размеры когорт
    conversion = conversion.drop(columns=['cohort_size'])
    # в таблице динамики оставляем только нужный лайфтайм
    conversion_history = conversion_history.drop(columns=['cohort_size'])[
        [horizon - 1]
    ]

    # первый график — кривые конверсии
    ax1 = plt.subplot(1, 2, 1)
    conversion.T.plot(grid=True, ax=ax1)
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Конверсия пользователей')

    # второй график — динамика конверсии
    ax2 = plt.subplot(1, 2, 2, sharey=ax1)
    columns = [
        # столбцами сводной таблицы станут все столбцы индекса, кроме даты
        name for name in conversion_history.index.names if name not in ['dt']
    ]
    filtered_data = conversion_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax2)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика конверсии пользователей на {}-й день'.format(horizon))

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ---

# %% [markdown]
# Создадим функция для визуализации LTV и ROI `plot_ltv_roi`.

# %%
def plot_ltv_roi(ltv, ltv_history, roi, roi_history, horizon, window=7):

    # задаём сетку отрисовки графиков
    plt.figure(figsize=(20, 10))

    # из таблицы ltv исключаем размеры когорт
    ltv = ltv.drop(columns=['cohort_size'])
    # в таблице динамики ltv оставляем только нужный лайфтайм
    ltv_history = ltv_history.drop(columns=['cohort_size'])[[horizon - 1]]

    # стоимость привлечения запишем в отдельный фрейм
    cac_history = roi_history[['cac']]

    # из таблицы roi исключаем размеры когорт и cac
    roi = roi.drop(columns=['cohort_size', 'cac'])
    # в таблице динамики roi оставляем только нужный лайфтайм
    roi_history = roi_history.drop(columns=['cohort_size', 'cac'])[
        [horizon - 1]
    ]

    # первый график — кривые ltv
    ax1 = plt.subplot(2, 3, 1)
    ltv.T.plot(grid=True, ax=ax1)
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('LTV')

    # второй график — динамика ltv
    ax2 = plt.subplot(2, 3, 2, sharey=ax1)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in ltv_history.index.names if name not in ['dt']]
    filtered_data = ltv_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax2)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика LTV пользователей на {}-й день'.format(horizon))

    # третий график — динамика cac
    ax3 = plt.subplot(2, 3, 3, sharey=ax1)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in cac_history.index.names if name not in ['dt']]
    filtered_data = cac_history.pivot_table(
        index='dt', columns=columns, values='cac', aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax3)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика стоимости привлечения пользователей')

    # четвёртый график — кривые roi
    ax4 = plt.subplot(2, 3, 4)
    roi.T.plot(grid=True, ax=ax4)
    plt.axhline(y=1, color='red', linestyle='--', label='Уровень окупаемости')
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('ROI')

    # пятый график — динамика roi
    ax5 = plt.subplot(2, 3, 5, sharey=ax4)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in roi_history.index.names if name not in ['dt']]
    filtered_data = roi_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax5)
    plt.axhline(y=1, color='red', linestyle='--', label='Уровень окупаемости')
    plt.xlabel('Дата привлечения')
    plt.title('Динамика ROI пользователей на {}-й день'.format(horizon))

    plt.tight_layout()
    plt.show()

# %% [markdown]
# **Вывод** - на даном этапе мы построили 8 функций:
#
# Это функции для вычисления значений метрик:
# - `get_profiles()` — для создания профилей пользователей
# - `get_retention(`) — для подсчёта Retention Rate
# - `get_conversion()` — для подсчёта конверсии
# - `get_ltv()` — для подсчёта LTV
#
# А также функции для построения графиков:
# - `filter_data()` — для сглаживания данных,
# - `plot_retention()` — для построения графика Retention Rate,
# - `plot_conversion()` — для построения графика конверсии,
# - `plot_ltv_roi()` — для визуализации LTV и ROI.

# %% [markdown]
# ### Шаг. Исследовательский анализ данных

# %% [markdown]
# #### Составим профили пользователей и определим минимальную и максимальную даты привлечения пользователей.

# %%
#построим таблицу с помощью функции
profiles = get_profiles(visit, order, costs)
#посмотрим 
display(profiles)
min_date_dt = profiles['dt'].min()
max_date_dt = profiles['dt'].max()

display(min_date_dt, max_date_dt)
# Out:
#              user_id            first_ts       channel  device         region  \
# 0             599326 2019-05-07 20:58:57      FaceBoom     Mac  United States
# 1            4919697 2019-07-09 12:46:07      FaceBoom  iPhone  United States
# 2            6085896 2019-10-01 09:58:33       organic  iPhone         France
# 3           22593348 2019-08-22 21:35:48    AdNonSense      PC        Germany
# 4           31989216 2019-10-02 00:07:44       YRabbit  iPhone  United States
# ...              ...                 ...           ...     ...            ...
# 150003  999956196527 2019-09-28 08:33:02        TipTop  iPhone  United States
# 150004  999975439887 2019-10-21 00:35:17       organic      PC             UK
# 150005  999976332130 2019-07-23 02:57:06        TipTop  iPhone  United States
# 150006  999979924135 2019-09-28 21:28:09  MediaTornado      PC  United States
# 150007  999999563947 2019-10-18 19:57:25       organic  iPhone  United States
#
# ...

# %% [markdown]
# **Вывод:**
# При вызове функциии get_profiles() и передачи ей данных о посещениях, покупках и тратах на рекламу - мы получили профили пользователей. Также нашли минимальную дату привечения пользователей это 1 мая 2019 г. и максимальную 27 октября 2019 г.

# %% [markdown]
# #### Выясним, из каких стран пользователи приходят в приложение и на какую страну приходится больше всего платящих пользователей. Построим таблицу, отражающую количество пользователей и долю платящих из каждой страны.

# %%
#сгруппируем таблицу с профилями пользователей по критерию страна
                                                 #и выведем общее количество клиентов, платящих и долю платящих
a = profiles.groupby('region')[['user_id','payer']]\
.agg(users = ('user_id', 'nunique'),
     payers = ('payer', 'sum'),
     payers_share = ('payer', lambda x: "{0:.2%}".format(x.mean())))\
.sort_values(by='users',ascending=False)
a
# Out:
#                 users  payers payers_share
# region
# United States  100002    6902        6.90%
# UK              17575     700        3.98%
# France          17450     663        3.80%
# Germany         14981     616        4.11%

# %% [markdown]
# **Вывод:**
# - По количеству пользователей лидирует `United States` 100002. Последнее место занимает `Germany` 14981.
# - По количеству платящих пользователей лидирует `United States` 6902. Последнее место занимает `Germany` 616.
# - По долям платящих пользователей лидирует `United States` 0.06. Последнее место занимает `Germany` 0.04.

# %% [markdown]
# #### Узнаем, какими устройствами пользуются клиенты и какие устройства предпочитают платящие пользователи. Построем таблицу, отражающую количество пользователей и долю платящих для каждого устройства.

# %%
#сгруппируем таблицу с профилями пользователей по критерию тип устройства
                                                 #и выведем общее количество клиентов, платящих и долю платящих
b = profiles.groupby('device')[['user_id','payer']]\
.agg(users_d = ('user_id', 'nunique'),
     payers_d = ('payer', 'sum'),
     payers_share_d = ('payer', lambda x: "{0:.2%}".format(x.mean())))\
.sort_values(by='payers_share_d',ascending=False)
b
# Out:
#          users_d  payers_d payers_share_d
# device
# Mac        30042      1912          6.36%
# iPhone     54479      3382          6.21%
# Android    35032      2050          5.85%
# PC         30455      1537          5.05%

# %% [markdown]
# **Вывод:**
# - По количеству пользователей лидирует `iPhone` 54479. Последнее место занимает `Mac` 30042.
# - По количеству платящих пользователей лидирует `iPhone` 3382. Последнее место занимает `Mac` 1912.
# - По долям платящих пользователей лидирует `Mac` 0.063. Последнее место занимает `PC` 0.05.

# %% [markdown]
# #### Изучим рекламные источники привлечения и определите каналы, из которых пришло больше всего платящих пользователей. Построим таблицу, отражающую количество пользователей и долю платящих для каждого канала привлечения.

# %%
#сгруппируем таблицу с профилями пользователей по критерию тип канала привлечения
                                                 #и выведем общее количество клиентов, платящих и долю платящих
с = profiles.groupby('channel')[['user_id','payer']]\
.agg(users_с = ('user_id', 'nunique'),
     payers_с = ('payer', 'sum'),
     payers_share_с = ('payer', lambda x: "{0:.2%}".format(x.mean())))\
.sort_values(by='payers_share_с',ascending=False)
с
# Out:
#                     users_с  payers_с payers_share_с
# channel
# TipTop                19561      1878          9.60%
# RocketSuperAds         4448       352          7.91%
# WahooNetBanner         8553       453          5.30%
# YRabbit                4312       165          3.83%
# MediaTornado           4364       156          3.57%
# LeapBob                8553       262          3.06%
# OppleCreativeMedia     8605       233          2.71%
# organic               56439      1160          2.06%
# FaceBoom              29144      3557         12.20%
# AdNonSense             3880       440         11.34%
# lambdaMediaAds         2149       225         10.47%

# %% [markdown]
# **Вывод:**
# - По количеству пользователей лидирует `organic` 56439. Последнее место занимает `lambdaMediaAds` 2149.
# - По количеству платящих пользователей лидирует `FaceBoom` 3557. Последнее место занимает `MediaTornado` 156.
# - По долям платящих пользователей лидирует `FaceBoom` 0.12. Последнее место занимает `organic` 0.02.

# %% [markdown]
# **Общий вывод:**
#
# На данном шаге, мы произвели следующие действия:
# * составили портрет пользователя при помощи функции `get_profiles()`. Определили минимальную и максимуальныю даты привлечения пользователей - это 1 мая и 27 октября 2019 года.
# * выявили на какую страну приходится больше всего пользователей - США (100002) из них 7% платящие - лучше дургих конвертируются. Меньше всего пользователей пришли из Германии 4,1% платящих пользователей.
# * определили какими устройствами предпочитают пользоваться платящие пользователи Мас (6.3%), относительно их общего колличества. В меньшей степени на ПК (5%), большая часть пользователей заходит с мобильных устройств,
# * выявили каналы, из которых приходит больше всего платящих пользователей - FaceBoom (29144 всего) и 12.2% платящие пользователи. lambdaMediaAds (2149 всего) и 10.4% платящие пользователи.

# %% [markdown]
# ### Шаг. Маркетинг

# %% [markdown]
# #### Посчитайте общую сумму расходов на маркетинг.

# %%
#возьмем таблицу с затратами на рекламу и суммируем их
marceting_sum = round(costs['costs'].sum(),1)
marceting_sum
# Out:
# 105497.3

# %% [markdown]
# **Вывод:**
# - Общая сумма на маркетинг составила 105497,3.

# %% [markdown]
# #### Выясните, как траты распределены по рекламным источникам, то есть сколько денег потратили на каждый источник.

# %%
#возьмем таблицу с затратами сгруппируем их по источнику и сумируем
costs_channel = costs.groupby('channel')\
.agg({'costs':'sum'})\
.sort_values(by='costs',ascending=False)
costs_channel
# Out:
#                        costs
# channel
# TipTop              54751.30
# FaceBoom            32445.60
# WahooNetBanner       5151.00
# AdNonSense           3911.25
# OppleCreativeMedia   2151.25
# RocketSuperAds       1833.00
# LeapBob              1797.60
# lambdaMediaAds       1557.60
# MediaTornado          954.48
# YRabbit               944.22

# %% [markdown]
# **Вывод топ 3 источника по затратам и источник с самым маленьким бюджетом:**
#
# ТОП 3
# - TipTop 54751.30
# - FaceBoom 32445.60
# - WahooNetBanner 5151.00
#
# Источник с самым маленьким бюджетом:
# - YRabbit 944.22

# %% [markdown]
# #### Постройте визуализацию динамики изменения расходов во времени (по неделям и месяцам) по каждому источнику. Постарайтесь отразить это на одном графике.

# %%
costs['dt'] = pd.to_datetime(costs['dt'])

# %%
#Построим гафики в ряд

ax1 = plt.subplot(2, 2, 1)
costs.groupby(by=[pd.Grouper(key='dt', freq='1W'), 'channel'])['costs'].agg('sum').unstack()\
.plot(ax = ax1, figsize=(15, 15), grid = True)
plt.title('Динамика изменения расходов по неделям')
plt.xlabel('Недели')
plt.ylabel('Затраты на рекламу');

ax2 = plt.subplot(2, 2, 2, sharey = ax1)
costs.groupby(by=[pd.Grouper(key='dt', freq='1M'), 'channel'])['costs'].agg('sum').unstack()\
.plot(ax = ax2, grid = True)
plt.title('Динамика изменения расходов по месяцам')
plt.xlabel('Месяцы')
plt.ylabel('Затраты на рекламу');

#посмотрим на результат
plt.show()

# %% [markdown]
# **Подведем итог:**
# В разрезе динамики по неделям, отметим, что больше всего затрат на рекламу получили два канала "Tip Top" и "Faceboom". Конце сентября у двух каналов был значительный подъем.
# В разрезе месяца мы наблюдаем значительный рост трат на рекламу у канала "Tip Top" в сетнябре.

# %% [markdown]
# #### Узнаем, сколько в среднем стоит привлечение одного пользователя (CAC) из каждого источника. Используйте профили пользователей.

# %%
#постороим таблицу с средним значением трат на рекламу
display(profiles.groupby('channel').agg({'acquisition_cost':'mean'}).sort_values(by='acquisition_cost',ascending=False))
#выведем значения на график
profiles.pivot_table(index = 'channel', values = 'acquisition_cost', aggfunc='mean')\
.plot(kind = 'bar',grid = True).set_title('Стоимость привлечения одного пользователя');
plt.xlabel('Каналы привлечения')
plt.ylabel('Средняя стоимость привлечения')
plt.show()

#Выведем средний САС по проекту.
mean_cac = profiles.groupby('channel').agg({'acquisition_cost':'mean'}).sort_values(by='acquisition_cost',ascending=False)
print('Средний САС по проекту равен', round(mean_cac['acquisition_cost'].mean(),1))
# Out:
#                     acquisition_cost
# channel
# TipTop                      2.799003
# FaceBoom                    1.113286
# AdNonSense                  1.008054
# lambdaMediaAds              0.724802
# WahooNetBanner              0.602245
# RocketSuperAds              0.412095
# OppleCreativeMedia          0.250000
# YRabbit                     0.218975
# MediaTornado                0.218717
# LeapBob                     0.210172
# organic                     0.000000
# Средний САС по проекту равен 0.7

# %% [markdown]
# **Подведем итог:**
# По графику отметим, что средняя сумма привлечения одного пользователя в `Tip Top` 2.8 y.e. На втором месте `FaceBoom` 1.1 y.e. Ну и стоимость пользователей, которые перешли к нам органическим способом, т.е. сами равна 0.

# %% [markdown]
# **Общий вывод:**
# В данном шаге, мы
# * посчитали общую сумму затрат на маркетинг, она составила 105497.3
# * выявили бюджет каждого канала привлечения на первом месте TipTop с общей суммой в 54751.30 - больше половины общего бюджета. Следом идет FaceBoom 32445.60. И на последнем месте YRabbit 944.22
# * посторили визуализацию расходов во времени , где обнаружили резкий рост трат на рекламу у TipTop (в 6 раз) и FaceBoom (в раза). Так и выходит средняя стоимость пользователя TipTop 2.8 у.е. А FaceBoom 1.1 у.е. И средний САС по проекту 0.7 у.е. Однако конвертация из неплатящих в платище у канала TipTop низкая. Это можно объяснить молодой аудиторией TipTop'a и, соответственно, не очень высокой их платежеспособностью.

# %% [markdown]
# ### Шаг . Оценим окупаемость рекламы

# %% [markdown]
# Используя графики LTV, ROI и CAC, проведем анализ окупаемости рекламы. На календаре 1 ноября 2019 года, а в бизнес-плане заложено, что пользователи должны окупаться не позднее чем через две недели после привлечения.

# %%
#исключим пользователей с органическим трафиком, поскольку мы за них ничего не платим.
profiles = profiles.query('channel != "organic"')

# %% [markdown]
# #### Проанализируем окупаемость рекламы c помощью графиков LTV и ROI, а также графики динамики LTV, CAC и ROI.

# %%
# считаем LTV и ROI
ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles, order, observation_date, horizon_days)
#строим графики
plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days)

# %% [markdown]
# **Подведем итог:**
# По графикам можно сделать следующие выводы:
# * Реклама не окупилась в конце второй недели ROI составил 80%.
# * Затраты на САС в конце второй недели подскочили в 4 раза по отношению к началу.
# * Наблюдаем, что динамика ROI за лайфтайм падает. При относительно стабильной динамике LTV, динамика САС растёт с мая по конец октября. Эту закономерность мы наблюдаем в динамике ROI, что при сильном увеличении САС, в равной степени падает динамика ROI пользователей.

# %% [markdown]
# #### Проверим конверсию пользователей и динамику её изменения. То же самое сделайте с удержанием пользователей. Постройте и изучите графики конверсии и удержания.

# %% [markdown]
# ##### Страны

# %% [markdown]
# <div align="center"><b> Конверсия </b></div>

# %%
dimensions=['region']
#Посмотрим на конверсию пользователей по регионам
conversion_raw, conversion_grouped, conversion_history = get_conversion(
    profiles, order, observation_date, horizon_days, dimensions=dimensions
)
#Постороим график 
plot_conversion(conversion_grouped, conversion_history, horizon_days)

# %% [markdown]
# **Подведем итоги:**
# Мы провели расчет конверсии пользователей по регионам, по графикам отчеливо видно, что пользователи из Сша конвертируются намного лучше остальных пользователей с других регионов. Хуже всего конвертируются пользователи из Франции. Посмотрим на удержание пользователей по регионам.

# %% [markdown]
# <div align="center"><b> Удержание </b></div>

# %%
#Посмотрим на удержание платящих и неплатящих пользователей
retention_raw, retention_grouped, retention_history = get_retention(
    profiles, visit, observation_date, horizon_days, dimensions=dimensions
)

plot_retention(retention_grouped, retention_history, horizon_days)

# %% [markdown]
# **Подведем итоги:**
# Мы провели расчет удержания пользователей по регионам, по графикам отчеливо видно, что платящие пользователи США удерживаются слабее остальных, чем пользователи из остальных регионов. Удержание неплатящих пользователей стабильно.

# %% [markdown]
# ##### Устройства

# %% [markdown]
# <div align="center"><b> Конверсия </b></div>

# %%
dimensions=['device']
#Посмотрим на конверсию пользователей по регионам
conversion_raw, conversion_grouped, conversion_history = get_conversion(
    profiles, order, observation_date, horizon_days, dimensions=dimensions
)
#Постороим график 
plot_conversion(conversion_grouped, conversion_history, horizon_days)

# %% [markdown]
# <div align="center"><b> Удержание </b></div>

# %%
#Посмотрим на удержание платящих и неплатящих пользователей
retention_raw, retention_grouped, retention_history = get_retention(
    profiles, visit, observation_date, horizon_days, dimensions=dimensions
)

plot_retention(retention_grouped, retention_history, horizon_days)

# %% [markdown]
# **Подведем итоги:**
# * Хорошо конвертирутся пользователи Мас и Iphon
# * Удерживаются пользователи всех девайсов примерно в одной поре, но пользователи РС показывают более хорошие результаты.

# %% [markdown]
# ##### Рекламные каналы

# %% [markdown]
# <div align="center"><b> Конверсия </b></div>

# %%
dimensions=['channel']
#Посмотрим на конверсию пользователей по регионам
conversion_raw, conversion_grouped, conversion_history = get_conversion(
    profiles, order, observation_date, horizon_days, dimensions=dimensions
)
#Постороим график 
plot_conversion(conversion_grouped, conversion_history, horizon_days)

# %% [markdown]
# <div align="center"><b> Удержание </b></div>

# %%
#Посмотрим на удержание платящих и неплатящих пользователей
retention_raw, retention_grouped, retention_history = get_retention(
    profiles, visit, observation_date, horizon_days, dimensions=dimensions
)

plot_retention(retention_grouped, retention_history, horizon_days)

# %% [markdown]
# **Подведем итоги:**
# * Хорошо конвертирутся пользователи каналов FaceBoom и AdNonSense
# * Удерживаются пользователи FaceBoom и AdNonSense хуже , чем пользователи всех остальных каналов.

# %% [markdown]
# #### Проанализируем окупаемость рекламы с разбивкой по устройствам. Построем графики LTV и ROI, а также графики динамики LTV, CAC и ROI.

# %%
dimensions = ['device']
# считаем LTV и ROI
ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles, order, observation_date, horizon_days, dimensions=dimensions
)
#строим графики
plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days, window=21)

# %% [markdown]
# **Подведем итоги:**
# * Реклама окупилась только на PC, на остальных платформах - нет.
# * Затраты на привлечение пользователей Iphone и Mac выросла в 4 раза начиная с мая.
# * На показатель LTV влияет сезонный фактор.

# %% [markdown]
# #### Проанализируем окупаемость рекламы с разбивкой по странам. Построем графики LTV и ROI, а также графики динамики LTV, CAC и ROI.

# %%
dimensions = ['region']
# считаем LTV и ROI
ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles, order, observation_date, horizon_days, dimensions=dimensions,
)
#строим графики
plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days, window=21)

# %% [markdown]
# **Подведем довольно неожиданные итоги:**
# * Реклама окупилась на только в трех странах: Франция, Германия, Британия.
# * Затраты на привлечение пользователей США в динамике в 6 раза больше, чем в других странах.

# %% [markdown]
# #### Проанализируем окупаемость рекламы с разбивкой по рекламным каналам. Построем графики LTV и ROI, а также графики динамики LTV, CAC и ROI.

# %%
dimensions = ['channel']
# считаем LTV и ROI
ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles, order, observation_date, horizon_days, dimensions=dimensions
)
#строим графики
plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days, window=21)

# %% [markdown]
# **Подведем итоги:**
# * По графику с LTV мы видим, что больше всего дс принесла `lambdaMediaAds`относительно своих показателей.
# * Каналы - лидер по затратам `TipTop`и `FaceBoom` не оправдал надежд.
# * Хотелось бы также отметить канал `YRabbit`, который показал хорошие результаты в июле.

# %% [markdown]
# **Подведем общие итоги:**
#
# * первым делом удалили органических пользователей, поскольку за них мы ничего не платим.
#
# * проанализировали окупаемость рекламы и выявили , что реклама не окупилась в конце второй недели, ROI составил 80%. Затраты на САС в конце второй недели подскочили в 4 раза по отношению к началу. На показатель LTV влияет сезонный фактор, этот показатель достаточно стабилен. Однозначно проблема не в ухудшении качества пользователей.Показатель ROI пользователей близится ниже отметки уровня окупаемости после 06 июля.
#
# * по итогам проверки конерсии и динамики ее изменения по странам, а так же удержания и дианамики , пришли к выводу, что пользователи из США конверируются лучше пользвотелей остальных регонов, но удерживаются хуже.
#
# * по итогам анализа окупаемости рекламы с разбивкой по устройствам, сделаны заключения реклама окупилась только на PC, на остальных платформах - нет. Затраты на привлечение пользователей Iphone и Mac выросла в 4 раза начиная с мая.На показатель LTV влияет сезонный фактор.
#
# * по итогам анализа окупаемости рекламы с разбивкой по устройствам, реклама окупилась на только в трех странах: Франция, Германия, Британия. Затраты на привлечение пользователей США в динамике в 6 раза больше, чем в других странах.
#
# * по итогам анализа окупаемости рекламы с разбивкой по рекламным каналам, было установлено по графику с LTV мы видим, что больше всего дс принесла lambdaMediaAds относительно своих показателей. Каналы - лидер по затратам TipTop и FaceBoom не оправдал надежд. Хотелось бы также отметить канал YRabbit, который показал хорошие

# %% [markdown]
# #### Окупается ли реклама, направленная на привлечение пользователей в целом?

# %% [markdown]
# Из пункта 5.1 `Проанализируем окупаемость рекламы c помощью графиков LTV и ROI, а также графики динамики LTV, CAC и ROI.` Мы видим, что ROI близится к отметке окупаемости 80% , но за 14 дней рекламная компания не окупилась.

# %% [markdown]
# #### Какие устройства, страны и рекламные каналы могут оказывать негативное влияние на окупаемость рекламы?

# %% [markdown]
# <div align="center"><b> устройства </b></div>

# %% [markdown]
# По данным полученым из пункта 5.3 `Проанализируем окупаемость рекламы с разбивкой по устройствам. Построем графики LTV и ROI, а также графики динамики LTV, CAC и ROI.`
#
# Негативное влияние на окупаемость рекламы прямо вляют следующие устройства: `Mac`, `Iphon` пользователи с данными устройствами не окупают рекламу ROI порядка 70%.

# %% [markdown]
# <div align="center"><b> страны </b></div>

# %% [markdown]
# По данным полученым из пункта 5.4 `Проанализируем окупаемость рекламы с разбивкой по страна. Построем графики LTV и ROI, а также графики динамики LTV, CAC и ROI.`
#
# Негативное влияние на окупаемость рекламы прямо вляют пользователи из США, так как они не окупаются.

# %% [markdown]
# <div align="center"><b> рекламные каналы </b></div>

# %% [markdown]
# По данным полученым из пункта 5.5 `Проанализируем окупаемость рекламы с разбивкой по страна. Построем графики LTV и ROI, а также графики динамики LTV, CAC и ROI.`
#
# Негативное влияние на окупаемость рекламы прямо вляют следующий рекламные каналы: TipTop, FaceBoom, тк бюджет у данных каналов большой, а окупаемость очень низкая.

# %% [markdown]
# #### Чем могут быть вызваны проблемы окупаемости?

# %% [markdown]
# Основной проблемой на мой взгляд является неправильное распределение средств на рекламные каналы, на один канал в сумме заложено больше средств , чем на остальные. Я бы в равной степени выделил бюджет на все рекламные каналы и отталкивался от тех, которые принесли больше прибыли. Также оносительно стран, урезать рекламный бюджет США и распреелить средства на другие страны или перераспределил бюджет на реламные площадки в США, которые приносят больше профита.

# %% [markdown]
# ### Шаг . Напишите выводы

# %% [markdown]
# #### Выделим причины неэффективности привлечения пользователей.

# %% [markdown]
# LTV растет, пользователи оставляют больше денежных средств, но и затраты на рекламу растут кратно. В сумме затрат на рекламу значительно больше нежели прибыли, поэтому затраты на рекламу не окупаются по истечению 14 дней, ROI пробивает уровень окупаемости в сторону убыточности.
# Рассмотрим более детайльно каждую из характиристик:
# * устройства пользователей - iPhone, Android, PC, Mac
# * страна пользователей - United States, UK, France, Germany
# * канал привлечения - FaceBoom, TipTop, OppleCreativeMedia,	LeapBob, WahooNetBanner, RocketSuperAds, MediaTornado, YRabbit, AdNonSense, lambdaMediaAds

# %% [markdown]
# По устройствам - Неравномерное распределение бюджета на рекламу. Основной упор сделали на продукцию от `Apple`, но в итоге выбор не оправдал ожиданий, а приложение окупилось у пользователей с `РС`.

# %% [markdown]
# По стране пользователей:
# * По колличеству пользователей, скачавших приложение, первое место занимает США 100002 пользователя, 7% из них доля платящих, примерно в равных долях Британия и Франция по ~ 17.5к скачавших приложение, как по ~ 4% платящих пользователей, последнее место занимает Германия ~ 15к общее количество и 5% платящих пользователей.
# * По динамике LTV США занимает первое место, в связи с тем , что из США нагнали большое количство пользователей, стоимость за пользователя (САС) там кратно выше, по сравнению с другими странами, но ROI постардал и затраты на рекламу не окупили себя, в отличии от отсальных стран (реклама в Германии , Франции, Британии окупилась)

# %% [markdown]
# По каналам привлечения:
# * Отметим рекламный канал, в который вложено большое количество бюджета - `TipTop`, данный канал не окупил себя самый низкий показатель ROI
# * Низкий уровень конвертации у каналов `YRabbit`, `RocketSuperAds`, `MediaTornado`

# %% [markdown]
# #### Сформулируйте рекомендации для отдела маркетинга.

# %% [markdown]
# * **Устройства**:
# по графику ROI мы заметили, что окупились пользователи с устройством РС, хотя основной упор маркетологи сделали на пользователей с устройствами фирмы Applе, которые не окупились. Удержаваются пользователи РС дольше. Хотя и бюджет на рекламу не большой в отношении остальных платформ. Необходимо перераспределить бюджет и приоритетом поставить пользователей с РС.
#
# * **Страны**:
# Большую часть рекламного бюджета ушло на пользователей из США. ROI не окупился и держался ~ 70%, в динамике был постепенный спад. Конверсия у пользователей из США хорошая , в разы выше пользователей из отсальных стран. А удержание платящих пользователей, к сожалению ниже. Решением будет разделить бюджет в равных долях между странами и выявить лидера, захватить рынок в данном сегменте в этой стране , путем финансирования каналов, которые приносят больше всего окупаемости.
#
# * **Каналы продвижения**:
# Бюджет на каналы продвижения маркетинговым отделом распределен некорректно, в связи с большими тратами на канал TipTop (больше половины бюджета), а данный источник не оправдал своих ожиданий, в связи с тем, что аудитория молодая и неплатежеспособная, такая жк проблема замечена и в FaceBoom. Необходимо в равной степени финанансировать выбранные каналы продвижения и определить лидера по окупаемости , как к примеру канал - YRabbit.
