# %% [markdown]
# <h1>Проектная работа: Принятие решений в бизнесе на основе A/B-тестирования.<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Описание-данных" data-toc-modified-id="Описание-данных-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Описание данных</a></span></li><li><span><a href="#Часть-1.-Приоритизация-гипотез." data-toc-modified-id="Часть-1.-Приоритизация-гипотез.-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Часть 1. Приоритизация гипотез.</a></span><ul class="toc-item"><li><span><a href="#Применим-фреймворк-ICE-для-приоритизации-гипотез.-Отсортируем-их-по-убыванию-приоритета." data-toc-modified-id="Применим-фреймворк-ICE-для-приоритизации-гипотез.-Отсортируем-их-по-убыванию-приоритета.-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Применим фреймворк ICE для приоритизации гипотез. Отсортируем их по убыванию приоритета.</a></span></li><li><span><a href="#Применим-фреймворк-RICE-для-приоритизации-гипотез.-Отсортируем-их-по-убыванию-приоритета." data-toc-modified-id="Применим-фреймворк-RICE-для-приоритизации-гипотез.-Отсортируем-их-по-убыванию-приоритета.-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Применим фреймворк RICE для приоритизации гипотез. Отсортируем их по убыванию приоритета.</a></span></li><li><span><a href="#Укажите,-как-изменилась-приоритизация-гипотез-при-применении-RICE-вместо-ICE.-Объясните,-почему-так-произошло." data-toc-modified-id="Укажите,-как-изменилась-приоритизация-гипотез-при-применении-RICE-вместо-ICE.-Объясните,-почему-так-произошло.-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Укажите, как изменилась приоритизация гипотез при применении RICE вместо ICE. Объясните, почему так произошло.</a></span></li></ul></li><li><span><a href="#Часть-2.-Анализ-A/B-теста" data-toc-modified-id="Часть-2.-Анализ-A/B-теста-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Часть 2. Анализ A/B-теста</a></span><ul class="toc-item"><li><span><a href="#Анализ-A/B-теста:" data-toc-modified-id="Анализ-A/B-теста:-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Анализ A/B-теста:</a></span><ul class="toc-item"><li><span><a href="#Построим-график-кумулятивной-выручки-по-группам.-Сделайте-выводы-и-предположения." data-toc-modified-id="Построим-график-кумулятивной-выручки-по-группам.-Сделайте-выводы-и-предположения.-3.1.1"><span class="toc-item-num">3.1.1&nbsp;&nbsp;</span>Построим график кумулятивной выручки по группам. Сделайте выводы и предположения.</a></span></li><li><span><a href="#Построим-график-кумулятивного-среднего-чека-по-группам.-Сделаем-выводы-и-предположения.-" data-toc-modified-id="Построим-график-кумулятивного-среднего-чека-по-группам.-Сделаем-выводы-и-предположения.--3.1.2"><span class="toc-item-num">3.1.2&nbsp;&nbsp;</span>Построим график кумулятивного среднего чека по группам. Сделаем выводы и предположения. <a id="section_id"></a></a></span></li><li><span><a href="#Построим-график-относительного-изменения-кумулятивного-среднего-чека-группы-B-к-группе-A.-Сделаем-выводы-и-предположения." data-toc-modified-id="Построим-график-относительного-изменения-кумулятивного-среднего-чека-группы-B-к-группе-A.-Сделаем-выводы-и-предположения.-3.1.3"><span class="toc-item-num">3.1.3&nbsp;&nbsp;</span>Построим график относительного изменения кумулятивного среднего чека группы B к группе A. Сделаем выводы и предположения.</a></span></li><li><span><a href="#Постройте-график-кумулятивного-среднего-количества-заказов-на-посетителя-по-группам.-Сделайте-выводы-и-предположения." data-toc-modified-id="Постройте-график-кумулятивного-среднего-количества-заказов-на-посетителя-по-группам.-Сделайте-выводы-и-предположения.-3.1.4"><span class="toc-item-num">3.1.4&nbsp;&nbsp;</span>Постройте график кумулятивного среднего количества заказов на посетителя по группам. Сделайте выводы и предположения.</a></span></li><li><span><a href="#Построим-график-относительного-изменения-кумулятивного-среднего-количества-заказов-на-посетителя-группы-B-к-группе-A.-Сделаем-выводы-и-предположения." data-toc-modified-id="Построим-график-относительного-изменения-кумулятивного-среднего-количества-заказов-на-посетителя-группы-B-к-группе-A.-Сделаем-выводы-и-предположения.-3.1.5"><span class="toc-item-num">3.1.5&nbsp;&nbsp;</span>Построим график относительного изменения кумулятивного среднего количества заказов на посетителя группы B к группе A. Сделаем выводы и предположения.</a></span></li><li><span><a href="#Построим-точечный-график-количества-заказов-по-пользователям.-Сделаем-выводы-и-предположения." data-toc-modified-id="Построим-точечный-график-количества-заказов-по-пользователям.-Сделаем-выводы-и-предположения.-3.1.6"><span class="toc-item-num">3.1.6&nbsp;&nbsp;</span>Построим точечный график количества заказов по пользователям. Сделаем выводы и предположения.</a></span></li><li><span><a href="#Посчитайте-95-й-и-99-й-перцентили-количества-заказов-на-пользователя.-Выберите-границу-для-определения-аномальных-пользователей." data-toc-modified-id="Посчитайте-95-й-и-99-й-перцентили-количества-заказов-на-пользователя.-Выберите-границу-для-определения-аномальных-пользователей.-3.1.7"><span class="toc-item-num">3.1.7&nbsp;&nbsp;</span>Посчитайте 95-й и 99-й перцентили количества заказов на пользователя. Выберите границу для определения аномальных пользователей.</a></span></li><li><span><a href="#Построим-точечный-график-стоимостей-заказов.-Сделайте-выводы-и-предположения." data-toc-modified-id="Построим-точечный-график-стоимостей-заказов.-Сделайте-выводы-и-предположения.-3.1.8"><span class="toc-item-num">3.1.8&nbsp;&nbsp;</span>Построим точечный график стоимостей заказов. Сделайте выводы и предположения.</a></span></li><li><span><a href="#Посчитаем-95-й-и-99-й-перцентили-стоимости-заказов.-Выберем-границу-для-определения-аномальных-заказов." data-toc-modified-id="Посчитаем-95-й-и-99-й-перцентили-стоимости-заказов.-Выберем-границу-для-определения-аномальных-заказов.-3.1.9"><span class="toc-item-num">3.1.9&nbsp;&nbsp;</span>Посчитаем 95-й и 99-й перцентили стоимости заказов. Выберем границу для определения аномальных заказов.</a></span></li><li><span><a href="#Посчитаем-статистическую-значимость-различий-в-среднем-количестве-заказов-на-посетителя-между-группами-по-«сырым»-данным.-Сделаем-выводы-и-предположения." data-toc-modified-id="Посчитаем-статистическую-значимость-различий-в-среднем-количестве-заказов-на-посетителя-между-группами-по-«сырым»-данным.-Сделаем-выводы-и-предположения.-3.1.10"><span class="toc-item-num">3.1.10&nbsp;&nbsp;</span>Посчитаем статистическую значимость различий в среднем количестве заказов на посетителя между группами по «сырым» данным. Сделаем выводы и предположения.</a></span></li><li><span><a href="#Посчитаем-статистически-значимые-различия-в-среднем-чеке-заказа-между-группами-по-«сырым»-данным.-Сделаем-выводы-и-предположения." data-toc-modified-id="Посчитаем-статистически-значимые-различия-в-среднем-чеке-заказа-между-группами-по-«сырым»-данным.-Сделаем-выводы-и-предположения.-3.1.11"><span class="toc-item-num">3.1.11&nbsp;&nbsp;</span>Посчитаем статистически значимые различия в среднем чеке заказа между группами по «сырым» данным. Сделаем выводы и предположения.</a></span></li><li><span><a href="#Посчитайте-статистическую-значимость-различий-в-среднем-количестве-заказов-на-посетителя-между-группами-по-«очищенным»-данным.-Сделайте-выводы-и-предположения." data-toc-modified-id="Посчитайте-статистическую-значимость-различий-в-среднем-количестве-заказов-на-посетителя-между-группами-по-«очищенным»-данным.-Сделайте-выводы-и-предположения.-3.1.12"><span class="toc-item-num">3.1.12&nbsp;&nbsp;</span>Посчитайте статистическую значимость различий в среднем количестве заказов на посетителя между группами по «очищенным» данным. Сделайте выводы и предположения.</a></span></li><li><span><a href="#Посчитаем-статистическую-значимость-различий-в-среднем-чеке-заказа-между-группами-по-«очищенным»-данным.-Сделаем-выводы-и-предположения." data-toc-modified-id="Посчитаем-статистическую-значимость-различий-в-среднем-чеке-заказа-между-группами-по-«очищенным»-данным.-Сделаем-выводы-и-предположения.-3.1.13"><span class="toc-item-num">3.1.13&nbsp;&nbsp;</span>Посчитаем статистическую значимость различий в среднем чеке заказа между группами по «очищенным» данным. Сделаем выводы и предположения.</a></span></li></ul></li></ul></li></ul></div>

# %% [markdown]
# В данном проекте из открытых источников представлены три датассета:
# * hypothesis.csv
# * orders.csv
# * visitors.csv
#
# В описании данных описсан каждый из них.

# %% [markdown]
# **Цели проекта:**
#
# Необходимо приоритизировать гипотезы, запустить А/В тест на основе представленных данных и проанализировать результаты и выяснить - какая из гипотез приведет к наибольшему увеличению выручки.

# %% [markdown]
# **Описание данных**

# %% [markdown]
# <div align="center"><b>hypothesis </b></div>
# 9 гипотез по увеличению выручки интернет-магазина с указанными параметрами:
#
# * Hypothesis — краткое описание гипотезы;
# * Reach — охват пользователей по 10-балльной шкале;
# * Impact — влияние на пользователей по 10-балльной шкале;
# * Confidence — уверенность в гипотезе по 10-балльной шкале;
# * Efforts — затраты ресурсов на проверку гипотезы по 10-балльной шкале. Чем больше значение Efforts, тем дороже проверка гипотезы.

# %% [markdown]
# <div align="center"><b>orders </b></div>
# Результаты А/В теста.

# %% [markdown]
# * transactionId — идентификатор заказа;
# * visitorId — идентификатор пользователя, совершившего заказ;
# * date — дата, когда был совершён заказ;
# * revenue — выручка заказа;
# * group — группа A/B-теста, в которую попал заказ.

# %% [markdown]
# <div align="center"><b>visitors </b></div>
# Результаты А/В теста.

# %% [markdown]
# * date — дата;
# * group — группа A/B-теста;
# * visitors — количество пользователей в указанную дату в указанной группе A/B-теста

# %% [markdown]
# Сам проект будет делиться на две части. В первой части, произведем приоритизацию гипотез. Во второй части, проанализируем A/B-тест.

# %% [markdown]
# ---

# %% [markdown]
# ## Часть 1. Приоритизация гипотез.

# %%
#импортируем все библиотеки для работы с данными
import pandas as pd
import matplotlib.pyplot as plt
import datetime as dt
import numpy as np
import scipy.stats as stats
import requests
from urllib.parse import urlencode
from pandas.plotting import register_matplotlib_converters
import warnings
# конвертеры, которые позволяют использовать типы pandas в matplotlib  
register_matplotlib_converters()

# %% [markdown]
# Откроем дассет `hypothesis` для предварителього ознакомления.

# %%
# используем api 
base_url = 'https://cloud-api.yandex.net/v1/disk/public/resources/download?' 
public_key = 'https://disk.yandex.ru/d/ve2A4C0NlCPycQ' 
 
# получаем url 
final_url = base_url + urlencode(dict(public_key=public_key)) 
response = requests.get(final_url) 
download_url = response.json()['href'] 

# загружаем файл в hypothesis 
download_response = requests.get(download_url) 
hypothesis = pd.read_csv(download_url)

#заранее расширим вывод содержимого ячеек

pd.set_option('max_colwidth', 1000)
hypothesis
# Out:
#                                                                                                      Hypothesis  Reach  Impact  Confidence  Efforts
# 0            Добавить два новых канала привлечения трафика, что позволит привлекать на 30% больше пользователей      3      10           8        6
# 1                                     Запустить собственную службу доставки, что сократит срок доставки заказов      2       5           4       10
# 2  Добавить блоки рекомендаций товаров на сайт интернет магазина, чтобы повысить конверсию и средний чек заказа      8       3           7        3
# 3           Изменить структура категорий, что увеличит конверсию, т.к. пользователи быстрее найдут нужный товар      8       3           3        8
# 4                              Изменить цвет фона главной страницы, чтобы увеличить вовлеченность пользователей      3       1           1        1
# ...

# %% [markdown]
# В данном файле мы видим - всего представленно 9 гипотез, с параметрами:
# * Reach - количество пользователей, которых затронет изменение
# * Impact - на сколько сильно изменение повлияет на пользователей, их опыт и удовлетворение от продукта
# * Confidence - уверенность в том, что это изменение повлияет на пользователей именно так
# * Effort - сколько стоит протестировать гипотезу

# %%
#переведем названия столбцов в нижний регистр
hypothesis.columns = hypothesis.columns.str.lower()

# %% [markdown]
# ### Применим фреймворк ICE для приоритизации гипотез. Отсортируем их по убыванию приоритета.

# %% [markdown]
# Исходя из вводных данных, применим формулу `Impact * Confidence / Efforts`

# %%
#найдем ICE
hypothesis['ice'] = round((hypothesis['impact'] * hypothesis['confidence'])/hypothesis['efforts'],2)
#получим результат
hypothesis[['hypothesis','ice']].sort_values(by = 'ice', ascending = False)
# Out:
#                                                                                                      hypothesis    ice
# 8                                                       Запустить акцию, дающую скидку на товар в день рождения  16.20
# 0            Добавить два новых канала привлечения трафика, что позволит привлекать на 30% больше пользователей  13.33
# 7              Добавить форму подписки на все основные страницы, чтобы собрать базу клиентов для email-рассылок  11.20
# 6          Показать на главной странице баннеры с актуальными акциями и распродажами, чтобы увеличить конверсию   8.00
# 2  Добавить блоки рекомендаций товаров на сайт интернет магазина, чтобы повысить конверсию и средний чек заказа   7.00
# 1                                     Запустить собственную службу доставки, что сократит срок доставки заказов   2.00
# 5                      Добавить страницу отзывов клиентов о магазине, что позволит увеличить количество заказов   1.33
# ...

# %% [markdown]
# **Вывод:**
#
# Благодаря методу приоритизаций гипотез `ice`.
# Мы определили:
# * первое место - `Запустить акцию, дающую скидку на товар в день рождения` (16,2)
#
# * второе место - `Добавить два новых канала привлечения трафика, что позволит привлекать на 30% больше пользователей` (13,3)
#
# * третье место - `Добавить форму подписки на все основные страницы, чтобы собрать базу клиентов для email-рассылок` (11,2)
#
# * четвертое место - `Показать на главной странице баннеры с актуальными акциями и распродажами, чтобы увеличить конверсию` (8,0)
#
# * пятое место - `Добавить блоки рекомендаций товаров на сайт интернет магазина, чтобы повысить конверсию и средний чек заказа` (7,0)

# %% [markdown]
# ### Применим фреймворк RICE для приоритизации гипотез. Отсортируем их по убыванию приоритета.

# %% [markdown]
# Исходя из вводных данных, применим формулу `Reach * Impact * Confidence / Efforts`

# %%
#найдем RICE
hypothesis['rice'] = (hypothesis['reach'] * hypothesis['impact'] * hypothesis['confidence']) / hypothesis['efforts']
#получим результат
hypothesis[['hypothesis','rice']].sort_values(by = 'rice', ascending = False)
# Out:
#                                                                                                      hypothesis   rice
# 7              Добавить форму подписки на все основные страницы, чтобы собрать базу клиентов для email-рассылок  112.0
# 2  Добавить блоки рекомендаций товаров на сайт интернет магазина, чтобы повысить конверсию и средний чек заказа   56.0
# 0            Добавить два новых канала привлечения трафика, что позволит привлекать на 30% больше пользователей   40.0
# 6          Показать на главной странице баннеры с актуальными акциями и распродажами, чтобы увеличить конверсию   40.0
# 8                                                       Запустить акцию, дающую скидку на товар в день рождения   16.2
# 3           Изменить структура категорий, что увеличит конверсию, т.к. пользователи быстрее найдут нужный товар    9.0
# 1                                     Запустить собственную службу доставки, что сократит срок доставки заказов    4.0
# ...

# %% [markdown]
# Вывод: Благодаря методу приоритизаций гипотез `rice`.
# Мы определили:
# * первое место - `Добавить форму подписки на все основные страницы, чтобы собрать базу клиентов для email-рассылок` (112)
#
# * второе место - `Добавить блоки рекомендаций товаров на сайт интернет магазина, чтобы повысить конверсию и средний чек заказа` (56)
#
# * третье место - `Добавить два новых канала привлечения трафика, что позволит привлекать на 30% больше пользователей` (40)
#
# * четвертое место - `Показать на главной странице баннеры с актуальными акциями и распродажами, чтобы увеличить конверсию` (40)
#
# * пятое место - `Запустить акцию, дающую скидку на товар в день рождения` (16,2)

# %% [markdown]
# ### Укажите, как изменилась приоритизация гипотез при применении RICE вместо ICE. Объясните, почему так произошло.

# %% [markdown]
# Приоритизация гипотез изменилась, так как к числителю добавился параметр `Reach` - количество пользователей, которых затронет изменение. Также в топовых позициях произошли смещения.

# %% [markdown]
# ## Часть 2. Анализ A/B-теста

# %% [markdown]
# Для выполнения второй части проекта нам потребуются данные из таблиц `orders.csv` и `visitors.csv`.

# %%
#открываем таблицу orders.csv
# используем api 
base_url = 'https://cloud-api.yandex.net/v1/disk/public/resources/download?' 
public_key = 'https://disk.yandex.ru/d/TVuvd3Iilar9Mg' 
 
# получаем url 
final_url = base_url + urlencode(dict(public_key=public_key)) 
response = requests.get(final_url) 
download_url = response.json()['href'] 
 
# загружаем файл в hypothesis 
download_response = requests.get(download_url) 
orders = pd.read_csv(download_url) 
display(orders)

#########################################################################################

#открываем таблицу visitors.csv
# используем api 
base_url = 'https://cloud-api.yandex.net/v1/disk/public/resources/download?' 
public_key = 'https://disk.yandex.ru/d/_y1hEEr4O5-3LA' 
 
# получаем url 
final_url = base_url + urlencode(dict(public_key=public_key)) 
response = requests.get(final_url) 
download_url = response.json()['href'] 
 
# загружаем файл в hypothesis 
download_response = requests.get(download_url) 
visitors = pd.read_csv(download_url) 
display(visitors)
# Out:
#       transactionId   visitorId        date  revenue group
# 0        3667963787  3312258926  2019-08-15     1650     B
# 1        2804400009  3642806036  2019-08-15      730     B
# 2        2961555356  4069496402  2019-08-15      400     A
# 3        3797467345  1196621759  2019-08-15     9759     B
# 4        2282983706  2322279887  2019-08-15     2308     B
# ...             ...         ...         ...      ...   ...
# 1192     2662137336  3733762160  2019-08-14     6490     B
# 1193     2203539145   370388673  2019-08-14     3190     A
# 1194     1807773912   573423106  2019-08-14    10550     A
# 1195     1947021204  1614305549  2019-08-14      100     A
# 1196     3936777065  2108080724  2019-08-15   202740     B
#
# [1197 rows x 5 columns]
#           date group  visitors
# 0   2019-08-01     A       719
# 1   2019-08-02     A       619
# 2   2019-08-03     A       507
# 3   2019-08-04     A       717
# 4   2019-08-05     A       756
# ..         ...   ...       ...
# ...

# %%
#проверим типы столбцов
display(visitors.info())
display(orders.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62 entries, 0 to 61
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   date      62 non-null     object
#  1   group     62 non-null     object
#  2   visitors  62 non-null     int64
# dtypes: int64(1), object(2)
# memory usage: 1.6+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1197 entries, 0 to 1196
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   transactionId  1197 non-null   int64
#  1   visitorId      1197 non-null   int64
#  2   date           1197 non-null   object
#  3   revenue        1197 non-null   int64
#  4   group          1197 non-null   object
# dtypes: int64(3), object(2)
# memory usage: 46.9+ KB
# None

# %%
#Приведем столбцы с датой к необходимому для анализа типу datetime
visitors['date'] = visitors['date'].map(
    lambda x: dt.datetime.strptime(x, '%Y-%m-%d'))
    
orders['date'] = orders['date'].map(
    lambda x: dt.datetime.strptime(x, '%Y-%m-%d'))

# %%
#Проверим на наличие дубликатов
display(visitors.duplicated().sum())
display(orders.duplicated().sum())
# Out:
# 0
# 0

# %%
#проверим типы столбцов
display(visitors.info())
display(orders.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62 entries, 0 to 61
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   date      62 non-null     datetime64[ns]
#  1   group     62 non-null     object
#  2   visitors  62 non-null     int64
# dtypes: datetime64[ns](1), int64(1), object(1)
# memory usage: 1.6+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1197 entries, 0 to 1196
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   transactionId  1197 non-null   int64
#  1   visitorId      1197 non-null   int64
#  2   date           1197 non-null   datetime64[ns]
#  3   revenue        1197 non-null   int64
#  4   group          1197 non-null   object
# dtypes: datetime64[ns](1), int64(3), object(1)
# memory usage: 46.9+ KB
# None

# %%
#Посмотрим сколько групп в АВ-тесте
display(visitors['group'].unique())
display(orders['group'].unique())
# Out:
# array(['A', 'B'], dtype=object)
# array(['B', 'A'], dtype=object)

# %%
#Изучим временной интервал, узнав даты начала и окончания теста
display(visitors.sort_values(by = 'date', ascending = False))
display(visitors['date'].min())
display(visitors['date'].max())
# Out:
#          date group  visitors
# 61 2019-08-31     B       718
# 30 2019-08-31     A       699
# 29 2019-08-30     A       490
# 60 2019-08-30     B       490
# 28 2019-08-29     A       577
# ..        ...   ...       ...
# 33 2019-08-03     B       509
# 32 2019-08-02     B       581
# 1  2019-08-02     A       619
# 0  2019-08-01     A       719
# 31 2019-08-01     B       713
#
# [62 rows x 3 columns]
# Timestamp('2019-08-01 00:00:00')
# Timestamp('2019-08-31 00:00:00')

# %%
#Рассмотрим количество пользователей в каждой группе - по таблице с заказами
display(orders.loc[orders['group'] == 'A']['visitorId'].count())
display(orders.loc[orders['group'] == 'A']['visitorId'].nunique())

display(orders.loc[orders['group'] == 'B']['visitorId'].count())
display(orders.loc[orders['group'] == 'B']['visitorId'].nunique())
# Out:
# 557
# 503
# 640
# 586

# %%
#Посмотреть не попадают ли какие-то пользователи в обе группы - по таблице с заказами.
display(orders.groupby('visitorId').agg({'group' : 'nunique'}).query('group>1').count())

double_users = orders.groupby('visitorId').agg({'group' : 'nunique'}).reset_index().query('group>1')['visitorId'].unique()
double_users
# Out:
# group    58
# dtype: int64
# array([   8300375,  199603092,  232979603,  237748145,  276558944,
#         351125977,  393266494,  457167155,  471551937,  477780734,
#         818047933,  963407295, 1230306981, 1294878855, 1316129916,
#        1333886533, 1404934699, 1602967004, 1614305549, 1648269707,
#        1668030113, 1738359350, 1801183820, 1959144690, 2038680547,
#        2044997962, 2378935119, 2458001652, 2579882178, 2587333274,
#        2600415354, 2654030115, 2686716486, 2712142231, 2716752286,
#        2780786433, 2927087541, 2949041841, 2954449915, 3062433592,
#        3202540741, 3234906277, 3656415546, 3717692402, 3766097110,
#        3803269165, 3891541246, 3941795274, 3951559397, 3957174400,
#        3963646447, 3972127743, 3984495233, 4069496402, 4120364173,
#        4186807279, 4256040402, 4266935830], dtype=int64)

# %%
#Посмотрим динамику посетителей по дням по группам (visitos).
visitorsA = visitors.query('group == "A"')
visitorsB = visitors.query('group == "B"')

fig,(p1,p2) = plt.subplots(1,2)
visitorsA.groupby('date').agg({'visitors':'sum'}).plot(
    ax = p1,kind = 'bar',grid= True, figsize=(15,7), title = 'Динамика посетителей группы А по дням', xlabel = 'Дата', ylabel = 'Колчество пользователей')

visitorsB.groupby('date').agg({'visitors':'sum'}).plot(
    ax = p2,kind = 'bar',grid= True, figsize=(15,7), title = 'Динамика посетителей группы В по дням', xlabel = 'Дата', ylabel = 'Колчество пользователей');

# %%
#Посмотрим динамику посетителей по дням по группам (visitos).
visitorsA = visitors.query('group == "A"')
visitorsB = visitors.query('group == "B"')

plt.figure(figsize=(15,7))
plt.grid()
plt.ylim(300, 800)

# Строим график выручки группы А
plt.plot(visitorsA['date'], visitorsA['visitors'], label='A')
plt.plot(visitorsB['date'], visitorsB['visitors'], label='B')

plt.title('Динамика посетителей по дням по группам', alpha=0.5, color="b", fontsize=15,)
plt.legend();

# %% [markdown]
# **Вывод:**
#
# * У нас есть два датафрейма с следующими типам полей: object, int64.
# * Первым делом мы поменяли тип у столбцов с датами с `object` на `datetime64[ns]` для дальнейшего удобства анализа.
# * Дубликатов в таблице обнаружено не было.
# * В АВ тесте принимали участие две группы А и В
# * Дата начала АВ теста `2019-08-01`, дата конца `2019-08-31`
# * В группе А всего 557 человек (503 уникальные). В группе В всего 640 человек (586 уникальные).
# * Общее количество поьзователей, которые попали в две группы 58 человек.
# * По динамике посещений у группы А можно выделить 5,13,26 числа, в которые было больше всего пользователей. По динамике посещений у группы В можно выделить 4,13,14,18 числа, в которые было больше всего пользователей.

# %% [markdown]
# ### Анализ A/B-теста:

# %% [markdown]
# #### Построим график кумулятивной выручки по группам. Сделайте выводы и предположения.

# %%
# создадим массив уникальных пар значений дат и групп теста
datesGroups = orders[['date', 'group']].drop_duplicates()

# получаем агрегированные кумулятивные по дням данные о заказах 
ordersAggregated = datesGroups.apply(
    lambda x: orders[
        np.logical_and(
            orders['date'] <= x['date'], orders['group'] == x['group']
        )
    ].agg(
        {
            'date': 'max',
            'group': 'max',
            'transactionId': 'nunique',
            'visitorId': 'nunique',
            'revenue': 'sum',
        }
    ),
    axis=1,
).sort_values(by=['date', 'group'])

# получаем агрегированные кумулятивные по дням данные о посетителях интернет-магазина 
visitorsAggregated = datesGroups.apply(
    lambda x: visitors[
        np.logical_and(
            visitors['date'] <= x['date'], visitors['group'] == x['group']
        )
    ].agg({'date': 'max', 'group': 'max', 'visitors': 'sum'}),
    axis=1,
).sort_values(by=['date', 'group'])

# объединяем кумулятивные данные в одной таблице и присваиваем названия
cumulativeData = ordersAggregated.merge(
    visitorsAggregated, left_on=['date', 'group'], right_on=['date', 'group']
)
cumulativeData.columns = [
    'date',
    'group',
    'orders',
    'buyers',
    'revenue',
    'visitors',
]

# датафрейм с кумулятивным количеством заказов и кумулятивной выручкой по дням в группе А
cumulativeRevenueA = cumulativeData[cumulativeData['group']=='A'][['date','revenue', 'orders']]

# датафрейм с кумулятивным количеством заказов и кумулятивной выручкой по дням в группе B
cumulativeRevenueB = cumulativeData[cumulativeData['group']=='B'][['date','revenue', 'orders']]

plt.figure(figsize=(15,7))

# Строим график выручки группы А
plt.plot(cumulativeRevenueA['date'], cumulativeRevenueA['revenue'], label='A')

# Строим график выручки группы B
plt.plot(cumulativeRevenueB['date'], cumulativeRevenueB['revenue'], label='B')

plt.title('График кумулятивной выручки по группам', alpha=0.5, color="b", fontsize=15,)
plt.xlabel('Дата')
plt.ylabel('Выручка')
plt.grid()
plt.legend();

# %% [markdown]
# **Вывод:**
#
# Выручка в группе `B` явно выходит больше, чем в группе `А`. И по графику видно, что что с количеством прошедших дней она только больше у группы `B`. Большой толчок был 19 числа, причиной служит увеличение числа дорогих заказов, этому свидетельствует увеличение среднего чека, см. [п 3.1.2](#section_id) .

# %% [markdown]
# #### Построим график кумулятивного среднего чека по группам. Сделаем выводы и предположения. <a id='section_id'></a>

# %%
#Разделим выручку на количество заказов и построим плот
plt.figure(figsize=(15,7))
plt.plot(cumulativeRevenueA['date'], cumulativeRevenueA['revenue']/cumulativeRevenueA['orders'], label='A')
plt.plot(cumulativeRevenueB['date'], cumulativeRevenueB['revenue']/cumulativeRevenueB['orders'], label='B')
plt.grid()
plt.title('График кумулятивного среднего чека по группам', alpha=0.5, color="b", fontsize=15,)
plt.xlabel('Дата')
plt.ylabel('Средний чек')
plt.legend();

# %% [markdown]
# **Вывод:**
#
# Средний чек у группы `B` в основной своей массе больше чем у группы `А`, но 13 числа ситуация изменилась и значение среднего чека стало больше у группы `А`, чем у группы `В` (единичный случай). Большой скачок был также с 19 числа и средний чек у группы `B` кратно вырос.

# %% [markdown]
# #### Построим график относительного изменения кумулятивного среднего чека группы B к группе A. Сделаем выводы и предположения.

# %%
# собираем данные в одном датафрейме
mergedCumulativeRevenue = cumulativeRevenueA.merge(cumulativeRevenueB, left_on='date', right_on='date', how='left', suffixes=['A', 'B'])

plt.figure(figsize=(15,7))

# cтроим отношение средних чеков
plt.plot(mergedCumulativeRevenue['date'], (mergedCumulativeRevenue['revenueB']/mergedCumulativeRevenue['ordersB'])/(mergedCumulativeRevenue['revenueA']/mergedCumulativeRevenue['ordersA'])-1)

# добавляем ось X
plt.axhline(y=0, color='black', linestyle='--') 
plt.grid()
plt.title('Изменения кумулятивного среднего чека группы B к группе A', alpha=0.5, color="b", fontsize=15,)
plt.xlabel('Дата')
plt.ylabel('Средний чек');

# %% [markdown]
# **Вывод:**
#
# На графике можно наблюдать сильную флуктуацию, что может нам говорить о наличии выбросов - т.е. внушительных покупок, так например  4.08.2019, 8.08.2019, 19.08.2019, но 13 числа был спад.

# %% [markdown]
# #### Постройте график кумулятивного среднего количества заказов на посетителя по группам. Сделайте выводы и предположения.

# %%
cumulativeData['conversion'] = cumulativeData['orders']/cumulativeData['visitors']
# отделяем данные по группе A
cumulativeDataA = cumulativeData[cumulativeData['group']=='A']

# отделяем данные по группе B
cumulativeDataB = cumulativeData[cumulativeData['group']=='B']

plt.figure(figsize=(15,7))
# строим графики
plt.plot(cumulativeDataA['date'], cumulativeDataA['conversion'], label='A')
plt.plot(cumulativeDataB['date'], cumulativeDataB['conversion'], label='B')
plt.legend()
plt.grid()
plt.title('График кумулятивного среднего количества заказов на посетителя по группам', alpha=0.5, color="b", fontsize=15,)
plt.xlabel('Дата')
plt.ylabel('Конверсия');
#plt.axis(["2019-08-01", '2019-09-01', 0, 0.04]);

# %% [markdown]
# **Вывод:**
#
# Конверсия группы `А` 3 августа показывает пиковое значение. И после резко снижается и фиксируетсяв пределах показателя в 30%. Конверсия группы `В` на протяжении всего эксперемента имеет динамичный характер, пик был 10 числа и фиксация в педелах 35 - 34%.

# %% [markdown]
# #### Построим график относительного изменения кумулятивного среднего количества заказов на посетителя группы B к группе A. Сделаем выводы и предположения.

# %%
#Соединим две таблицы в одну по дате 
mergedCumulativeConversions = cumulativeDataA[['date','conversion']].merge(cumulativeDataB[['date','conversion']], left_on='date', right_on='date', how='left', suffixes=['A', 'B'])

plt.figure(figsize=(15,7))
plt.plot(mergedCumulativeConversions['date'], mergedCumulativeConversions['conversionB']/mergedCumulativeConversions['conversionA']-1, label="Относительный прирост конверсии группы B относительно группы A")
plt.legend()
plt.grid()

plt.axhline(y=0, color='black', linestyle='--')
plt.axhline(y=-0.1, color='grey', linestyle='--')
plt.axis(["2019-08-01", '2019-09-01', -0.2, 0.3]);

# %% [markdown]
# **Вывод:**
#
# По графику видно, что конверсия группы `В` стабилизируется на отметке роста с 10 - 20% по отношению к группе `А`, но до 5 числа они находились на одном уровне.

# %% [markdown]
# #### Построим точечный график количества заказов по пользователям. Сделаем выводы и предположения.

# %%
#Построим таблицу по пользователям

ordersBYuser = orders.groupby('visitorId', as_index=False).agg({'transactionId':'nunique'})
ordersBYuser.columns = ['userId', 'orders']

#выберем ось Х
x_values = pd.Series(range(0, len(ordersBYuser)))

#Построим плот
plt.title('График количества заказов по пользователям', alpha=0.5, color="b", fontsize=15,)

plt.ylabel('Количество заказов')
plt.xlabel('Пользователи')
plt.text(0, 10, "Одна точка - один пользователь", fontsize=9)

plt.scatter(x_values, ordersBYuser['orders']);

# %% [markdown]
# **Вывод:**
#
# По графику видно, что в основном пользователи делают 2 заказа, есть и выбросы пользователи, которые сделали более 10 заказов.

# %% [markdown]
# #### Посчитайте 95-й и 99-й перцентили количества заказов на пользователя. Выберите границу для определения аномальных пользователей.

# %%
per_count_orders = np.percentile(ordersBYuser['orders'], [95, 99])
per_count_orders
# Out:
# array([2., 4.])

# %% [markdown]
# **Вывод:**
#
# 5% пользователей делали заказ более 2 раз, 1% пользователей делали больше 4 заказов. Возьмем за верхний показатель количество заказов - 3.

# %% [markdown]
# #### Построим точечный график стоимостей заказов. Сделайте выводы и предположения.

# %%
#Построим таблицу по заказам

ordersBYrevenue = orders[['transactionId', 'revenue']]  #.groupby('transactionId', as_index=False).agg({'revenue':'sum'})
ordersBYrevenue.columns = ['orders', 'revenue']

#выберем ось Х
x_values = pd.Series(range(0, len(ordersBYrevenue)))

#Построим плот
plt.title('График график стоимостей заказов', alpha=0.5, color="b", fontsize=15,)

plt.ylabel('Стоимость заказа')
plt.xlabel('Заказ')
plt.text(0, 1100000, "Одна точка - один заказ", fontsize=9)
plt.grid()

plt.scatter(x_values, ordersBYrevenue['revenue']);

# %% [markdown]
# **Вывод:**
#
# У нас есть аномальный заказ на 1.2 у.е. и еще один 0.2 у.е.

# %%
#Ограничим ось Y и рассмотрим оснувную часть заказов
#Построим таблицу по заказам

ordersBYrevenue = orders[['transactionId', 'revenue']]  #.groupby('transactionId', as_index=False).agg({'revenue':'sum'})
ordersBYrevenue.columns = ['orders', 'revenue']

#выберем ось Х
x_values = pd.Series(range(0, len(ordersBYrevenue)))

#Построим плот
plt.title('График график стоимостей заказов', alpha=0.5, color="b", fontsize=15,)

plt.ylabel('Стоимость заказа')
plt.xlabel('Заказ')

plt.ylim(0, 100000)
plt.grid()

plt.scatter(x_values, ordersBYrevenue['revenue']);

# %% [markdown]
# **Вывод:**
#
# Рассмотрим основное количество заказов, большую часть заказов отчетливо видно до 30 000, заказы свыше можно считать выбросами.

# %% [markdown]
# #### Посчитаем 95-й и 99-й перцентили стоимости заказов. Выберем границу для определения аномальных заказов.

# %%
per_sum_orders = np.percentile(ordersBYrevenue['revenue'], [95, 99])
per_sum_orders
# Out:
# array([28000. , 58233.2])

# %% [markdown]
# **Вывод:**
#
# 28 000 стоимость более 5% заказов, больше 1% стоимость заказов составляет 58 233. За потолок можно взять стоимость не более 58 233.

# %% [markdown]
# #### Посчитаем статистическую значимость различий в среднем количестве заказов на посетителя между группами по «сырым» данным. Сделаем выводы и предположения.

# %%
#Подготовка данных


#Найдем количество пользователей до выбранной даты включительно в группе A;
visitorsADaily = visitors[visitors['group'] == 'A'][['date', 'visitors']]
visitorsADaily.columns = ['date', 'visitorsPerDateA']

visitorsACummulative = visitorsADaily.apply(
    lambda x: visitorsADaily[visitorsADaily['date'] <= x['date']].agg(
        {'date': 'max', 'visitorsPerDateA': 'sum'}
    ),
    axis=1,
)
visitorsACummulative.columns = ['date', 'visitorsCummulativeA']

#Найдем количество пользователей до выбранной даты включительно в группе В;
visitorsBDaily = visitors[visitors['group'] == 'B'][['date', 'visitors']]
visitorsBDaily.columns = ['date', 'visitorsPerDateB']

visitorsBCummulative = visitorsBDaily.apply(
    lambda x: visitorsBDaily[visitorsBDaily['date'] <= x['date']].agg(
        {'date': 'max', 'visitorsPerDateB': 'sum'}
    ),
    axis=1,
)
visitorsBCummulative.columns = ['date', 'visitorsCummulativeB']



#Найдем количество заказов в выбранную дату в группе A - 'ordersPerDateA'
#и суммарную выручку в выбранной дате в группе A - 'revenuePerDateA'
ordersADaily = (
    orders[orders['group'] == 'A'][['date', 'transactionId', 'visitorId', 'revenue']]
    .groupby('date', as_index=False)
    .agg({'transactionId': pd.Series.nunique, 'revenue': 'sum'})
)
ordersADaily.columns = ['date', 'ordersPerDateA', 'revenuePerDateA']

#Найдем суммарное число заказов до выбранной даты включительно в группе A - 'ordersCummulativeA'
#и суммарную выручку до выбранной даты включительно в группе A - 'revenueCummulativeA'
ordersACummulative = ordersADaily.apply(
    lambda x: ordersADaily[ordersADaily['date'] <= x['date']].agg(
        {'date': 'max', 'ordersPerDateA': 'sum', 'revenuePerDateA': 'sum'}
    ),
    axis=1,
).sort_values(by=['date'])
ordersACummulative.columns = [
    'date',
    'ordersCummulativeA',
    'revenueCummulativeA',
]

#Найдем количество заказов в выбранную дату в группе В - 'ordersPerDateВ'
#и суммарную выручку в выбранной дате в группе В - 'revenuePerDateВ'
ordersBDaily = (
    orders[orders['group'] == 'B'][['date', 'transactionId', 'visitorId', 'revenue']]
    .groupby('date', as_index=False)
    .agg({'transactionId': pd.Series.nunique, 'revenue': 'sum'})
)
ordersBDaily.columns = ['date', 'ordersPerDateB', 'revenuePerDateB']

#Найдем суммарное число заказов до выбранной даты включительно в группе В - 'ordersCummulativeВ'
#и суммарную выручку до выбранной даты включительно в группе В - 'revenueCummulativeВ'
ordersBCummulative = ordersBDaily.apply(
    lambda x: ordersBDaily[ordersBDaily['date'] <= x['date']].agg(
        {'date': 'max', 'ordersPerDateB': 'sum', 'revenuePerDateB': 'sum'}
    ),
    axis=1,
).sort_values(by=['date'])
ordersBCummulative.columns = [
    'date',
    'ordersCummulativeB',
    'revenueCummulativeB',
]

#Сложим все в таблицу
data = (
    ordersADaily.merge(
        ordersBDaily, left_on='date', right_on='date', how='left'
    )
    .merge(ordersACummulative, left_on='date', right_on='date', how='left')
    .merge(ordersBCummulative, left_on='date', right_on='date', how='left')
    .merge(visitorsADaily, left_on='date', right_on='date', how='left')
    .merge(visitorsBDaily, left_on='date', right_on='date', how='left')
    .merge(visitorsACummulative, left_on='date', right_on='date', how='left')
    .merge(visitorsBCummulative, left_on='date', right_on='date', how='left')
)

print(data.head(5))
# Out:
#         date  ordersPerDateA  revenuePerDateA  ordersPerDateB  revenuePerDateB  ordersCummulativeA  revenueCummulativeA  ordersCummulativeB  revenueCummulativeB  visitorsPerDateA  visitorsPerDateB  visitorsCummulativeA  visitorsCummulativeB
# 0 2019-08-01              24           148579              21           101217                  24               148579                  21               101217               719               713                   719                   713
# 1 2019-08-02              20            93822              24           165531                  44               242401                  45               266748               619               581                  1338                  1294
# 2 2019-08-03              24           112473              16           114248                  68               354874                  61               380996               507               509                  1845                  1803
# ...

# %% [markdown]
# **Нулевая гипотеза** - Статистически значимых различий в конверсии между группами нет
#
# **Альтернативная гипотеза** - Статистически значимые различия есть.

# %%
#Посчитаем статистическую значимость различия в среднем количестве заказов между группами.

#Создадим переменные ordersByUsersA и ordersByUsersB со столбцами ['userId', 'orders'].
#В них для пользователей, которые заказывали хотя бы 1 раз, укажем число совершённых заказов. 
ordersByUsersA = (
    orders[orders['group'] == 'A']
    .groupby('visitorId', as_index=False)
    .agg({'transactionId': pd.Series.nunique})
)
ordersByUsersA.columns = ['userId', 'orders']

ordersByUsersB = (
    orders[orders['group'] == 'B']
    .groupby('visitorId', as_index=False)
    .agg({'transactionId': pd.Series.nunique})
)
ordersByUsersB.columns = ['userId', 'orders'] 

#Объявим переменные sampleA и sampleB, в которых пользователям из разных групп будет соответствовать количество заказов.
#Тем, кто ничего не заказал, будут соответствовать нули.
#Это нужно, чтобы подготовить выборки к проверке критерием Манна-Уитни.
sampleA = pd.concat(
    [
        ordersByUsersA['orders'],
        pd.Series(0, index=np.arange(data['visitorsPerDateA'].sum() - len(ordersByUsersA['orders'])), name='orders',),],
    axis=0,
)

sampleB = pd.concat(
    [
        ordersByUsersB['orders'],
        pd.Series(
            0,
            index=np.arange(
                data['visitorsPerDateB'].sum() - len(ordersByUsersB['orders'])
            ),
            name='orders',
        ),
    ],
    axis=0,
)

#Выведем относительный прирост среднего числа заказов группы B:
#среднее число заказов группы B / среднее число заказов группы A - 1.
#Округлим до трёх знаков после запятой.
print("p-value  {0:.3f}".format(stats.mannwhitneyu(sampleA, sampleB)[1]))
print("Различие в средних {0:.3f}".format(sampleB.mean() / sampleA.mean() - 1))
# Out:
# p-value  0.017
# Различие в средних 0.138

# %% [markdown]
# <div class="alert alert-warning">
# <h2> Комментарий ревьюера 🤓<a class="tocSkip"> </h2>
#
# В целом большая часть этого кода, до расчета статистической значимости избыточна, потому что ранее мы проводили данные вычисления)
#
# Чтобы не возникало путаницы, следует подписать значения, какое из них - p-value, а какое - различие в средних.
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента:</b> Исправил </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера 😊 v_2 <a class="tocSkip"> </h2>
#
# 👍

# %% [markdown]
# **Вывод:**
#
# Первое число — p-value = 0.017 меньше 0.05. Значит, нулевую гипотезу о том, что статистически значимых различий в среднем числе заказов между группами нет, отвергаем. Выигрыш группы B равен 14%.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера 😊<a class="tocSkip"> </h2>
#
# Значение p-value интерпретировано правильно. Хорошая работа.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера 🤔<a class="tocSkip"></h2>
#     <s>
# Отсутствуют статистические гипотезы по которым проводится проверка. Давай добавим нулевую и альтернативную гипотезы к каждому тесту)
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента:</b> Исправил </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера 😊 v_2 <a class="tocSkip"> </h2>
#
# Гипотезы сформулированы верно)

# %% [markdown]
# #### Посчитаем статистически значимые различия в среднем чеке заказа между группами по «сырым» данным. Сделаем выводы и предположения.

# %% [markdown]
# **Нулевая гипотеза** - Статистически значимых различий в среднем чеке между группами нет
#
# **Альтернативная гипотеза** - Статистически значимые различия есть.

# %%
print('P-value {0:.3f}'.format(stats.mannwhitneyu(orders[orders['group']=='A']['revenue'], orders[orders['group']=='B']['revenue'])[1]))
print('Выигрыш группы В {0:.3f}'.format(orders[orders['group']=='B']['revenue'].mean()/orders[orders['group']=='A']['revenue'].mean()-1))
# Out:
# P-value 0.729
# Выигрыш группы В 0.259

# %% [markdown]
# P-value значительно больше 0.05. Значит, причин отвергать нулевую гипотезу и считать, что в среднем чеке есть различия, нет.
# Выигрыш группы В составляет 26%, наблюдаемые различия не являются значимыми при таком уровне значимости, а следовательно были получены случайно.

# %% [markdown]
# <div class="alert alert-warning">
# <h2> Комментарий ревьюера 🤓<a class="tocSkip"> </h2>
#
# Стоит дополнить, что поскольку относительное различие среднего чека между сегментами составляет ~26%, наблюдаемые различия не являются значимыми при таком уровне значимости, а следовательно были получены случайно. </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента:</b> Исправил </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера 😊 v_2 <a class="tocSkip"> </h2>
#
# 👍

# %% [markdown]
# #### Посчитайте статистическую значимость различий в среднем количестве заказов на посетителя между группами по «очищенным» данным. Сделайте выводы и предположения.

# %% [markdown]
# Найденные в прошлых главах 95-й и 99-й перцентили средних чеков равны 28 000 и 58 233.2, потолком мы выбрали 58 233.2.
# А 95-й и 99-й перцентили количества заказов на одного пользователя равны 2 и 4 заказа на пользователя и потолком мы обозначили 3 заказа.
#
# Примем за аномальных пользователей тех, кто совершил от 3 заказов или совершил заказ дороже 58 233.2 рублей.

# %%
#Сделаем срезы пользователей с числом заказов больше 3 — `usersWithManyOrders` 
usersWithManyOrders = pd.concat(
    [
        ordersByUsersA[ordersByUsersA['orders'] > per_count_orders[0]]['userId'],
        ordersByUsersB[ordersByUsersB['orders'] > per_count_orders[0]]['userId'],
    ],
    axis=0,
)
display(usersWithManyOrders)


#Cовершившил заказы дороже 58 233.2  — `usersWithExpensiveOrders`
usersWithExpensiveOrders = orders[orders['revenue'] > per_sum_orders[1]]['visitorId']
abnormalUsers = (
    pd.concat([usersWithManyOrders, usersWithExpensiveOrders], axis=0)
    .drop_duplicates()
    .sort_values()
)

display(usersWithManyOrders)
# Out:
# 18      199603092
# 23      237748145
# 68      611059232
# 146    1230306981
# 189    1614305549
# 227    2038680547
# 237    2108163459
# 269    2378935119
# 278    2458001652
# 349    2988190573
# 456    3908431265
# 467    3967698036
# 499    4256040402
# 37      249864742
# 68      457167155
# 284    2038680547
# 326    2378935119
# 340    2458001652
# 360    2587333274
# 382    2742574263
# 424    3062433592
# 501    3717692402
# 514    3803269165
# 580    4256040402
# Name: userId, dtype: int64
# 18      199603092
# 23      237748145
# 68      611059232
# 146    1230306981
# 189    1614305549
# 227    2038680547
# 237    2108163459
# 269    2378935119
# 278    2458001652
# 349    2988190573
# 456    3908431265
# 467    3967698036
# 499    4256040402
# 37      249864742
# 68      457167155
# 284    2038680547
# 326    2378935119
# 340    2458001652
# 360    2587333274
# 382    2742574263
# 424    3062433592
# 501    3717692402
# 514    3803269165
# 580    4256040402
# ...

# %% [markdown]
# <div class="alert alert-warning">
# <h2> Комментарий ревьюера 🤓<a class="tocSkip"> </h2>
#
# Чтобы в дальнейшем мы могли использовать анализ повторно, будет лучше отказаться от  ручного ввода обозначаемых границ, и заменить на соответствующие коду обозначения (перцентили))
#
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента:</b> Вроде исправил, правильно понял же ? </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера 😊 v_2 <a class="tocSkip"> </h2>
#
# Верно, можно также использовать `np.percentile(ordersBYrevenue['revenue'], 99)`

# %% [markdown]
# **Нулевая гипотеза** - Статистически значимых различий в конверсии между группами нет
#
# **Альтернативная гипотеза** - Статистически значимые различия есть.

# %%
#Подготовим выборки количества заказов по пользователям по группам теста
sampleAFiltered = pd.concat(
    [
        ordersByUsersA[
            np.logical_not(ordersByUsersA['userId'].isin(abnormalUsers))
        ]['orders'],
        pd.Series(
            0,
            index=np.arange(
                data['visitorsPerDateA'].sum() - len(ordersByUsersA['orders'])
            ),
            name='orders',
        ),
    ],
    axis=0,
)

sampleBFiltered = pd.concat(
    [
        ordersByUsersB[
            np.logical_not(ordersByUsersB['userId'].isin(abnormalUsers))
        ]['orders'],
        pd.Series(
            0,
            index=np.arange(
                data['visitorsPerDateB'].sum() - len(ordersByUsersB['orders'])
            ),
            name='orders',
        ),
    ],
    axis=0,
)

print('P-value {0:.3f}'.format(stats.mannwhitneyu(sampleAFiltered, sampleBFiltered)[1]))
print('Различие в средних {0:.3f}'.format(sampleBFiltered.mean()/sampleAFiltered.mean()-1))
# Out:
# P-value 0.010
# Различие в средних 0.174

# %% [markdown]
# **Вывод:**
#
# Результаты по среднему количеству заказов у грязных данных было 1.7%, у очищенных снизилось до 1% и всеравно, это меньше чем 0.05 поэтому, нулевая гипотеза остается отвергнутой. И группа В лидирует над группой А в 17.4%.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера 🤔<a class="tocSkip"></h2>
#     <s>
# Давай уточним, были ли достигнуты различия по среднему количеству заказов.

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента:</b> Исправил </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера 😊 v_2 <a class="tocSkip"> </h2>
#
# Верно)

# %% [markdown]
# #### Посчитаем статистическую значимость различий в среднем чеке заказа между группами по «очищенным» данным. Сделаем выводы и предположения.

# %% [markdown]
# **Нулевая гипотеза** - Статистически значимых различий в среднем чеке между группами нет
#
# **Альтернативная гипотеза** - Статистически значимые различия есть.

# %%
print(
    'P-value {0:.3f}'.format(
        stats.mannwhitneyu(
            orders[
                np.logical_and(
                    orders['group'] == 'A',
                    np.logical_not(orders['visitorId'].isin(abnormalUsers)),
                )
            ]['revenue'],
            orders[
                np.logical_and(
                    orders['group'] == 'B',
                    np.logical_not(orders['visitorId'].isin(abnormalUsers)),
                )
            ]['revenue'],
        )[1]
    )
)

print(
    "Выигрыш группы В {0:.3f}".format(
        orders[
            np.logical_and(
                orders['group'] == 'B',
                np.logical_not(orders['visitorId'].isin(abnormalUsers)),
            )
        ]['revenue'].mean()
        / orders[
            np.logical_and(
                orders['group'] == 'A',
                np.logical_not(orders['visitorId'].isin(abnormalUsers)),
            )
        ]['revenue'].mean()
        - 1
    )
)
# Out:
# P-value 0.798
# Выигрыш группы В -0.020

# %% [markdown]
# **Вывод:**
#
# P-value 0.798 больше чем 0.729 (неочищенные данные). Значит нулевая гипотеза также остается неотвергнутой, т.е. статистически значимых различий в среднем чеке между группами нет, но разница между средними чеками сократилась с 26 до -2%, так как мы урезали заказ из группы В.

# %%
#тот самый заказ, который испортил статистику
orders.loc[orders['revenue'] == orders['revenue'].max()]
# Out:
#      transactionId   visitorId       date  revenue group
# 425      590470918  1920142716 2019-08-19  1294500     B

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера 🤔<a class="tocSkip"></h2>
#     <s>
# Давай поясним принимаем мы или отвергаем нулевую гипотезу и достигнуты ли различия)

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера 😊 v_2 <a class="tocSkip"> </h2>
#
# Правильно)

# %% [markdown]
# Выводы по А/В тестированию:
#
# * Сырые данные
#     * **Количество заказов на посетителя:** *Первое число — p-value = 0.017 меньше 0.05, это значит что различия в среднем числе заказов между группами есть и она составляет 14%*
#     * **Средний чек заказа между группами:** *P-value значительно больше 0.05, он равен 0.729, это значит что в среднем чеке нет различий, а выигрыш группы В 26%, проблема в одном аномальном заказе, который портит всю статистику *
#
# * Очищенные данные
#     * **Количество заказов на посетителя:** Различия в среднем числе заказов между группами есть и она составляет 17.4% в пользу группы В.
#     * **Средний чек заказа между группами:** P-value больше , чем 0.05, это означает что в среднем чеке нет различий, но средний чек группы В упал до минус 2% по отношению к группе А (убрали аномальные заказы).
#
# Общие меры - 3. Остановить тест, так как результаты тестирования вполне однозначны, в итоге можно принять решение остановить тестирование, так как группа В победила, но хоть и группа ведет на 2% по среднему чеку.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера 😊 v_2 <a class="tocSkip"> </h2>
#
# Верно)

# %% [markdown]
# <div class="alert alert-warning">
# <h2> Комментарий ревьюера 🤓 <a class="tocSkip"> </h2>
# Не будем забывать о проблеме подглядывания, почему ты хочешь продолжать тест? Если чтобы средний чек стабилизировался, то мы и так по нему не получили статестически значимых результатов - можно, конечно, посмотреть на мощность критерия, чтобы понять насколько достоверный результат мы имеем. Так же следует учитывать нужно это бизнесу: еще ждать несколько дней, если конверсия увеличилась, а качество пользователей осталось тем же? Сможем ли мы повлиять на это? Это те вопросы, на которые я советую поискать ответы, если мы хотим продолжать тест. Также ты можешь попробовать спрогнозировать, как долго нужно будет продолжать тест, воспользовавшись специальными сервисами.
#
# Примеры калькуляторов:
# http://www.evanmiller.org/ab-testing/sample-size.html
#
# https://www.optimizely.com/sample-size-calculator/?conversion=20&effect=5&significance=95
#
# https://vwo.com/tools/ab-test-duration-calculator/ </div>
#
# </div>

# %% [markdown]
# <div style="border:solid Purple 2px; padding: 40px">
#
# <h2> Общий комментарий ревьюера 😊 v_2<a class="tocSkip"> </h2>
#     <br/>
# Артем, спасибо за проект! Успехов в дальнейшем обучении!)

# %% [markdown]
# <div style="border:solid Purple 2px; padding: 40px">
#
# <h2> Общий комментарий ревьюера 😊<a class="tocSkip"> </h2>
#     <br/>
#  Артем, хорошо пораотал. Отлично справился с построением графиков и расчетами по статистическому анализу, осталось доработать несколько важных моментов)
#
# Необходимо доработать:
#
# * Добавить комментарии к графикам
# * Указать гипотезы
# * Дополнить выводы
# * Остальные комментарии ты найдешь в работе
#
#
# **Желаю удачи и жду твой проект на повторное ревью! Если вдруг у тебя возникнут вопросы, то я с радостью отвечу на них.    😊**
#
# ![gif](https://i.gifer.com/378.gif)
#
# <br>
#
# **Дополнительные материалы:**
#
# [Вебинары под эгидой Практикума](https://vk.com/yandex.praktikum?w=wall-176471180_2144),
#
# [Лекции Анатолия Карпова 1](https://www.youtube.com/watch?v=jnFVmtaeSA0&list=WL&index=19&t=2s) [2](https://www.youtube.com/watch?v=gljfGAkgX_o&list=WL&index=4)
#
# Материалы [gopractice](https://gopractice.ru/summary/)
#
# Лекцию Карта статистических методов [Смотреть видео](https://www.youtube.com/watch?v=-zps6hm0nX8&t=1269s)
#
# </div>
